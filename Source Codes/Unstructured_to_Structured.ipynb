# %% [raw]
# import pandas as pd
# import ast  # Use ast for safer evaluation of strings to dictionaries
#
# # Step 1: Load your DataFrame from the Excel file
# file_path = 'chennai_cars.xlsx'  # Your Excel file name
# df = pd.read_excel(file_path)
#
# # Step 2: Initialize an empty list to hold the structured data
# unwound_data = []
#
# # Step 3: Loop through each row of the DataFrame
# for index, row in df.iterrows():
#     # Initialize a dictionary for the current row
#     combined_data = {}
#
#     # Specify the columns containing dictionaries
#     dict_columns = ['new_car_detail', 'new_car_overview', 'new_car_feature', 'new_car_specs']
#
#     # Step 4: Extract and merge dictionaries from the specified columns
#     for col in dict_columns:
#         try:
#             # Safely convert the string representation of the dictionary to an actual dictionary
#             dict_value = ast.literal_eval(row[col])
#             if isinstance(dict_value, dict):
#                 combined_data.update(dict_value)  # Merge the extracted dictionary
#         except Exception as e:
#             print(f"Error parsing row {index}, column {col}: {e}")
#
#     # Append the combined data for the current row to the unwound data list
#     unwound_data.append(combined_data)
#
# # Step 5: Create a DataFrame from the unwound data
# unwound_df = pd.DataFrame(unwound_data)
#
# # Optional: Display the unwound DataFrame
# print(unwound_df)
#
# # Save the unwound DataFrame to a new Excel file if needed
# unwound_df.to_excel('unwound_chennai_cars.xlsx', index=False)

# %%
unwound_df.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner      oem  \
# 0   0  Petrol        SUV  20,000    Automatic        1  1st Owner      Kia
# 1   0  Petrol   Minivans  20,687       Manual        1  1st Owner   Maruti
# 2   0  Petrol        SUV  30,000       Manual        1  1st Owner   Nissan
# 3   0  Petrol  Hatchback  59,247       Manual        1  1st Owner  Hyundai
# 4   0  Petrol  Hatchback  50,000       Manual        1  1st Owner    Honda
#
#             model  modelYear  ...         price priceActual priceSaving  \
# 0       Kia Sonet       2022  ...  ₹ 11.50 Lakh
# 1     Maruti Eeco       2015  ...   ₹ 4.15 Lakh
# 2  Nissan Magnite       2021  ...   ₹ 7.50 Lakh
# 3     Hyundai i10       2015  ...   ₹ 3.98 Lakh
# 4      Honda Jazz       2015  ...   ₹ 5.50 Lakh
#
#   priceFixedText                                       trendingText  \
# 0           None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# ...

# %%
unwound_df.columns
# Out:
# Index(['it', 'ft', 'bt', 'km', 'transmission', 'ownerNo', 'owner', 'oem',
#        'model', 'modelYear', 'centralVariantId', 'variantName', 'price',
#        'priceActual', 'priceSaving', 'priceFixedText', 'trendingText',
#        'heading', 'top', 'bottomData', 'data', 'commonIcon'],
#       dtype='object')

# %%
import pandas as pd

# Step 1: Read the Excel file
df = pd.read_excel("chennai_cars.xlsx")

# Step 2: Initialize an empty list to hold structured data
structured_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    row_data = {}
    
    # Convert the string representation of the dictionary to an actual dictionary
    try:
        dict_value = eval(row['new_car_detail'])  # Replace eval with ast.literal_eval for safer evaluation
        if isinstance(dict_value, dict):
            row_data = dict_value
    except Exception as e:
        print(f"Error parsing row {index}: {e}")
        row_data = None

    # Append the row dictionary to the structured data list
    structured_data.append(row_data)

# Step 4: Create a DataFrame from the list of dictionaries in 'new_car_detail'
unwound_df = pd.json_normalize(structured_data)

# Optional: Display the unwound DataFrame
print(unwound_df)

# Save the unwound DataFrame to a new Excel file
#unwound_df.to_excel('unwound_new_car_detail.xlsx', index=False)
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV  20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans  20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV  30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback  59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback  50,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1414   0  Petrol  Hatchback  42,891    Automatic        1  1st Owner
# 1415   0  Diesel        SUV  59,100       Manual        1  1st Owner
# 1416   0  Petrol        SUV  55,913    Automatic        1  1st Owner
# 1417   0  Diesel        SUV  65,000    Automatic        1  1st Owner
# 1418   0  Diesel      Sedan  60,000    Automatic        1  1st Owner
#
#              oem              model  modelYear  centralVariantId  \
# 0            Kia          Kia Sonet       2022              8654
# ...

# %%
import pandas as pd

# Step 1: Read the Excel file
df = pd.read_excel("chennai_cars.xlsx")

# Step 2: Initialize an empty list to hold structured data
structured_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    row_data = {}
    
    # Convert the string representation of the dictionary to an actual dictionary
    try:
        dict_value = eval(row['new_car_overview'])  # Replace eval with ast.literal_eval for safer evaluation
        if isinstance(dict_value, dict):
            row_data = dict_value
    except Exception as e:
        print(f"Error parsing row {index}: {e}")
        row_data = None

    # Append the row dictionary to the structured data list
    structured_data.append(row_data)

# Step 4: Create a DataFrame from the list of dictionaries in 'new_car_detail'
unwound_df1 = pd.json_normalize(structured_data)

# Optional: Display the unwound DataFrame
print(unwound_df1)

# Save the unwound DataFrame to a new Excel file
#unwound_df.to_excel('unwound_new_car_detail.xlsx', index=False)
# Out:
#            heading                                                top  \
# 0     Car overview  [{'key': 'Registration Year', 'value': '2022',...
# 1     Car overview  [{'key': 'Registration Year', 'value': 'Feb 20...
# 2     Car overview  [{'key': 'Registration Year', 'value': '2021',...
# 3     Car overview  [{'key': 'Registration Year', 'value': 'May 20...
# 4     Car overview  [{'key': 'Registration Year', 'value': '2015',...
# ...            ...                                                ...
# 1414  Car overview  [{'key': 'Registration Year', 'value': 'Jun 20...
# 1415  Car overview  [{'key': 'Registration Year', 'value': 'Feb 20...
# 1416  Car overview  [{'key': 'Registration Year', 'value': 'Aug 20...
# 1417  Car overview  [{'key': 'Registration Year', 'value': 'Aug 20...
# 1418  Car overview  [{'key': 'Registration Year', 'value': 'Oct 20...
#
#      bottomData
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# ...         ...
# ...

# %%
import pandas as pd

# Step 1: Read the Excel file
df = pd.read_excel("chennai_cars.xlsx")

# Step 2: Initialize an empty list to hold structured data
structured_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    row_data = {}
    
    # Convert the string representation of the dictionary to an actual dictionary
    try:
        dict_value = eval(row['new_car_feature'])  # Replace eval with ast.literal_eval for safer evaluation
        if isinstance(dict_value, dict):
            row_data = dict_value
    except Exception as e:
        print(f"Error parsing row {index}: {e}")
        row_data = None

    # Append the row dictionary to the structured data list
    structured_data.append(row_data)

# Step 4: Create a DataFrame from the list of dictionaries in 'new_car_detail'
unwound_df2 = pd.json_normalize(structured_data)

# Optional: Display the unwound DataFrame
print(unwound_df2)

# Save the unwound DataFrame to a new Excel file
#unwound_df.to_excel('unwound_new_car_detail.xlsx', index=False)
# Out:
#        heading                                                top  \
# 0     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1     Features  [{'value': 'Low Fuel Warning Light'}, {'value'...
# 2     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 3     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 4     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# ...        ...                                                ...
# 1414  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1415  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1416  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1417  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1418  Features  [{'value': 'Power Steering'}, {'value': 'Power...
#
#                                                    data  \
# 0     [{'heading': 'Comfort & Convenience', 'subHead...
# 1     [{'heading': 'Comfort & Convenience', 'subHead...
# ...

# %%
import pandas as pd

# Step 1: Read the Excel file
df = pd.read_excel("chennai_cars.xlsx")

# Step 2: Initialize an empty list to hold structured data
structured_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    row_data = {}
    
    # Convert the string representation of the dictionary to an actual dictionary
    try:
        dict_value = eval(row['new_car_specs'])  # Replace eval with ast.literal_eval for safer evaluation
        if isinstance(dict_value, dict):
            row_data = dict_value
    except Exception as e:
        print(f"Error parsing row {index}: {e}")
        row_data = None

    # Append the row dictionary to the structured data list
    structured_data.append(row_data)

# Step 4: Create a DataFrame from the list of dictionaries in 'new_car_detail'
unwound_df3 = pd.json_normalize(structured_data)

# Optional: Display the unwound DataFrame
print(unwound_df3)

# Save the unwound DataFrame to a new Excel file
#unwound_df.to_excel('unwound_new_car_detail.xlsx', index=False)
# Out:
#              heading                                                top  \
# 0     Specifications  [{'key': 'Engine', 'value': '998 CC'}, {'key':...
# 1     Specifications  [{'key': 'Mileage', 'value': '15.37 kmpl'}, {'...
# 2     Specifications  [{'key': 'Mileage', 'value': '20 kmpl'}, {'key...
# 3     Specifications  [{'key': 'Mileage', 'value': '19.81 kmpl'}, {'...
# 4     Specifications  [{'key': 'Mileage', 'value': '18.7 kmpl'}, {'k...
# ...              ...                                                ...
# 1414  Specifications  [{'key': 'Mileage', 'value': '22 kmpl'}, {'key...
# 1415  Specifications  [{'key': 'Mileage', 'value': '19.87 kmpl'}, {'...
# 1416  Specifications  [{'key': 'Mileage', 'value': '17 kmpl'}, {'key...
# 1417  Specifications  [{'key': 'Mileage', 'value': '16.65 kmpl'}, {'...
# 1418  Specifications  [{'key': 'Mileage', 'value': '21.76 kmpl'}, {'...
#
#                                                    data commonIcon
# ...

# %%
import pandas as pd

# Assume df1, df2, df3, and df4 are your four DataFrames

# Concatenate the DataFrames column-wise
combined_df = pd.concat([unwound_df, unwound_df1, unwound_df2, unwound_df3], axis=1)

# Optional: Display the combined DataFrame
print(combined_df)

# Save the combined DataFrame to a new Excel file if needed
combined_df.to_excel('combined_data_column_wise.xlsx', index=False)
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV  20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans  20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV  30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback  59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback  50,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1414   0  Petrol  Hatchback  42,891    Automatic        1  1st Owner
# 1415   0  Diesel        SUV  59,100       Manual        1  1st Owner
# 1416   0  Petrol        SUV  55,913    Automatic        1  1st Owner
# 1417   0  Diesel        SUV  65,000    Automatic        1  1st Owner
# 1418   0  Diesel      Sedan  60,000    Automatic        1  1st Owner
#
#              oem              model  modelYear  ...  \
# 0            Kia          Kia Sonet       2022  ...
# ...

# %%
combined_df.columns
# Out:
# Index(['it', 'ft', 'bt', 'km', 'transmission', 'ownerNo', 'owner', 'oem',
#        'model', 'modelYear', 'centralVariantId', 'variantName', 'price',
#        'priceActual', 'priceSaving', 'priceFixedText', 'trendingText.imgUrl',
#        'trendingText.heading', 'trendingText.desc', 'heading', 'top',
#        'bottomData', 'heading', 'top', 'data', 'commonIcon', 'heading', 'top',
#        'data', 'commonIcon'],
#       dtype='object')

# %%
import pandas as pd

# Example DataFrame with repeating columns (for demonstration purposes)
# combined_df = pd.DataFrame(...)  # Assume this is your existing DataFrame

# Step 1: Get the current column names
original_columns = combined_df.columns

# Step 2: Create a new list to hold unique column names
new_columns = []
column_count = {}

# Step 3: Loop through original columns and create unique names
for col in original_columns:
    if col in column_count:
        column_count[col] += 1
        new_columns.append(f"{col}_{column_count[col]}")  # Append count as suffix
    else:
        column_count[col] = 1
        new_columns.append(col)  # Keep original name for the first occurrence

# Step 4: Assign the new column names to the DataFrame
combined_df.columns = new_columns

# Optional: Display the updated DataFrame columns
print(combined_df.columns)
# Out:
# Index(['it', 'ft', 'bt', 'km', 'transmission', 'ownerNo', 'owner', 'oem',
#        'model', 'modelYear', 'centralVariantId', 'variantName', 'price',
#        'priceActual', 'priceSaving', 'priceFixedText', 'trendingText.imgUrl',
#        'trendingText.heading', 'trendingText.desc', 'heading', 'top',
#        'bottomData', 'heading_2', 'top_2', 'data', 'commonIcon', 'heading_3',
#        'top_3', 'data_2', 'commonIcon_2'],
#       dtype='object')

# %%
combined_df.head(1)
# Out:
#    it      ft   bt      km transmission  ownerNo      owner  oem      model  \
# 0   0  Petrol  SUV  20,000    Automatic        1  1st Owner  Kia  Kia Sonet
#
#    modelYear  ...                                                top  \
# 0       2022  ...  [{'key': 'Registration Year', 'value': '2022',...
#
#   bottomData heading_2                                              top_2  \
# 0       None  Features  [{'value': 'Power Steering'}, {'value': 'Power...
#
#                                                 data  \
# 0  [{'heading': 'Comfort & Convenience', 'subHead...
#
#                                           commonIcon       heading_3  \
# 0  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg  Specifications
#
#                                                top_3  \
# 0  [{'key': 'Engine', 'value': '998 CC'}, {'key':...
#
#                                               data_2 commonIcon_2
# 0  [{'heading': 'Engine and Transmission', 'subHe...
#
# [1 rows x 30 columns]

# %%
import pandas as pd

# Function to extract and convert 'top1' into a DataFrame
def extract_top_to_dataframe(main_df):
    rows = []  # To hold the extracted data
    
    # Loop through each row in the main DataFrame
    for _, row in main_df.iterrows():
        top3_data = row['top_3']  # Access the list directly
        
        # Check if the top1_data is a list
        if isinstance(top3_data, list):
            # Create a dictionary from the extracted key-value pairs
            row_dict = {item['key']: item['value'] for item in top3_data if 'key' in item and 'value' in item}
            rows.append(row_dict)  # Add the dictionary to the rows list
        else:
            print(f"Unexpected format for row: {row}. Expected a list but got {type(top3_data)}")
    
    # Create a new DataFrame from the rows list
    top3_df = pd.DataFrame(rows)
    return top3_df

# Extracting the DataFrame from 'top1'
top3_df = extract_top_to_dataframe(combined_df)

# Display the new DataFrame
print(top3_df)
# Out:
#        Engine  Max Power   Torque Wheel Size Seats     Mileage
# 0      998 CC  118.36bhp    172nm         16     5         NaN
# 1     1196 CC      73bhp    101Nm        NaN     7  15.37 kmpl
# 2      999 CC   98.63bhp    160Nm         16     5     20 kmpl
# 3     1086 CC   68.05bhp  99.04Nm        NaN     5  19.81 kmpl
# 4     1199 CC    88.7bhp    110Nm         15     5   18.7 kmpl
# ...       ...        ...      ...        ...   ...         ...
# 1414  1197 CC   81.80bhp    113Nm        NaN     5     22 kmpl
# 1415  1461 CC    83.8bhp    200Nm         16     5  19.87 kmpl
# 1416  1198 CC   108.5bhp    170Nm         16     5     17 kmpl
# 1417  1968 CC     141bhp    340Nm         18     5  16.65 kmpl
# 1418  1995 CC     188bhp    400Nm         18     5  21.76 kmpl
#
# [1419 rows x 6 columns]

# %%
import pandas as pd

# Assuming combined_df is your existing DataFrame with a column named 'top_2'
# combined_df = ...  # Your existing DataFrame

def extract_list_of_dicts_to_dataframe(main_df, column_name):
    # Initialize a list to store the extracted data
    extracted_data = []

    for index, row in main_df.iterrows():
        # Check if the cell is a list and not empty
        if isinstance(row[column_name], list) and row[column_name]:
            # Create a dictionary from the extracted values
            row_dict = {item['value']: True for item in row[column_name]}
        else:
            row_dict = {}

        extracted_data.append(row_dict)

    # Create a DataFrame from the extracted data
    extracted_df = pd.DataFrame(extracted_data)

    return extracted_df

# Extract DataFrame for top_2
top_2_df = extract_list_of_dicts_to_dataframe(combined_df, 'top_2')

# Display the DataFrame
print("DataFrame for top_2:")
print(top_2_df)
# Out:
# DataFrame for top_2:
#      Power Steering Power Windows Front Air Conditioner Heater  \
# 0              True                True            True   True
# 1               NaN                 NaN             NaN   True
# 2              True                True            True   True
# 3              True                True            True   True
# 4              True                True            True   True
# ...             ...                 ...             ...    ...
# 1414           True                True            True   True
# 1415           True                True            True   True
# 1416           True                True            True   True
# 1417           True                True            True   True
# 1418           True                True            True   True
#
#      Adjustable Head Lights Fog Lights Front Anti Lock Braking System  \
# 0                      True             True                     True
# ...

# %%
import pandas as pd

# Function to extract and convert 'top1' into a DataFrame
def extract_top_to_dataframe(main_df):
    rows = []  # To hold the extracted data
    
    # Loop through each row in the main DataFrame
    for _, row in main_df.iterrows():
        top_data = row['top']  # Access the list directly
        
        # Check if the top1_data is a list
        if isinstance(top_data, list):
            # Create a dictionary from the extracted key-value pairs
            row_dict = {item['key']: item['value'] for item in top_data if 'key' in item and 'value' in item}
            rows.append(row_dict)  # Add the dictionary to the rows list
        else:
            print(f"Unexpected format for row: {row}. Expected a list but got {type(top_data)}")
    
    # Create a new DataFrame from the rows list
    top_df = pd.DataFrame(rows)
    return top_df

# Extracting the DataFrame from 'top1'
top_df = extract_top_to_dataframe(combined_df)

# Display the new DataFrame
print(top_df)
# Out:
#      Registration Year     Insurance Validity Fuel Type    Seats  Kms Driven  \
# 0                 2022  Third Party insurance    Petrol  5 Seats  20,000 Kms
# 1             Feb 2015          Comprehensive    Petrol  7 Seats  20,687 Kms
# 2                 2021  Third Party insurance    Petrol  5 Seats  30,000 Kms
# 3             May 2015          Comprehensive    Petrol  5 Seats  59,247 Kms
# 4                 2015  Third Party insurance    Petrol  5 Seats  50,000 Kms
# ...                ...                    ...       ...      ...         ...
# 1414          Jun 2018  Third Party insurance    Petrol  5 Seats  42,891 Kms
# 1415          Feb 2019  Third Party insurance    Diesel  5 Seats  59,100 Kms
# 1416          Aug 2018          Not Available    Petrol  5 Seats  55,913 Kms
# 1417          Aug 2017          Comprehensive    Diesel  5 Seats  65,000 Kms
# 1418          Oct 2019          Comprehensive    Diesel  5 Seats  60,000 Kms
#
# ...

# %%
# Inspect the 'data' column in combined_df
print(combined_df['data'].head(5))  # Display the first 5 rows of the 'data' column
# Out:
# 0    [{'heading': 'Comfort & Convenience', 'subHead...
# 1    [{'heading': 'Comfort & Convenience', 'subHead...
# 2    [{'heading': 'Comfort & Convenience', 'subHead...
# 3    [{'heading': 'Comfort & Convenience', 'subHead...
# 4    [{'heading': 'Comfort & Convenience', 'subHead...
# Name: data, dtype: object

# %%
import pandas as pd

def extract_data_to_dataframe(main_df, column_name):
    # Create a list to hold the rows for the new DataFrame
    data_rows = []
    
    # Iterate over each row in the main DataFrame
    for index, row in main_df.iterrows():
        # Check if the cell is a list and contains dictionaries
        if isinstance(row[column_name], list) and row[column_name]:
            # Extract the 'list' field from the first dictionary in the row
            list_values = row[column_name][0].get('list', [])
            # Create a dictionary to hold values for this row
            row_dict = {item['value']: True for item in list_values}
            # Append the dictionary to the rows list
            data_rows.append(row_dict)
        else:
            # If there's no data, append an empty dictionary
            data_rows.append({})

    # Create a DataFrame from the list of dictionaries
    data_df = pd.DataFrame(data_rows)

    return data_df

# Extract DataFrame for the 'data' column
data_df = extract_data_to_dataframe(combined_df, 'data')

# Display the DataFrame
print("DataFrame for data:")
print(data_df)
# Out:
# DataFrame for data:
#      Power Steering Power Windows Front Power Windows Rear  \
# 0              True                True               True
# 1               NaN                 NaN                NaN
# 2              True                True               True
# 3              True                True               True
# 4              True                True               True
# ...             ...                 ...                ...
# 1414           True                True               True
# 1415           True                True               True
# 1416           True                True               True
# 1417           True                True               True
# 1418           True                True               True
#
#      Low Fuel Warning Light Accessory Power Outlet Trunk Light  \
# 0                      True                   True        True
# 1                      True                   True         NaN
# ...

# %%
import pandas as pd

def extract_data2_to_dataframe(main_df, column_name):
    # Create a list to hold the rows for the new DataFrame
    data_rows = []
    
    # Iterate over each row in the main DataFrame
    for index, row in main_df.iterrows():
        # Check if the cell is a list and contains dictionaries
        if isinstance(row[column_name], list) and row[column_name]:
            # Create a dictionary to hold values for this row
            row_dict = {}
            for section in row[column_name]:
                # Extract the 'list' field from each section
                for item in section.get('list', []):
                    # Use the 'key' as the column name and 'value' as the value
                    row_dict[item['key']] = item['value']
            # Append the dictionary to the rows list
            data_rows.append(row_dict)
        else:
            # If there's no data, append an empty dictionary
            data_rows.append({})

    # Create a DataFrame from the list of dictionaries
    data2_df = pd.DataFrame(data_rows)

    return data2_df

# Extract DataFrame for the 'data_2' column
data2_df = extract_data2_to_dataframe(combined_df, 'data_2')

# Display the DataFrame
print("DataFrame for data_2:")
print(data2_df)
# Out:
# DataFrame for data_2:
#        Color                               Engine Type Displacement  \
# 0      Black                  Smartstream G1.0 T - GDi          998
# 1       Grey                            In-Line Engine         1196
# 2     Others                     HRA0 1.0 TURBO PETROL          999
# 3     Silver                              IRDE2 Engine         1086
# 4     Others                      i-VTEC Petrol Engine         1199
# ...      ...                                       ...          ...
# 1414    Blue                               VTVT Engine         1197
# 1415  Orange                     dCi THP Diesel Engine         1461
# 1416   White         Revotron 1.2L Turbocharged engine         1198
# 1417    Grey              Common Rail Direct Injection         1968
# 1418   White  TwinPower Turbo 4-Cylinder Diesel Engine         1995
#
#               Max Power          Max Torque  No of Cylinder  \
# 0     118.36bhp@6000rpm  172nm@1500-4000rpm             3.0
# ...

# %%
import pandas as pd

# Assuming combined_df, top_df, top3_df, data2_df, top_2_df, data_df are already defined

# Concatenate the DataFrames column-wise
final_df_chennai = pd.concat([combined_df, top_df, top3_df, data2_df, top_2_df, data_df], axis=1)

# Display the final DataFrame
print("Final DataFrame (final_df_chennai):")
print(final_df_chennai)
# Out:
# Final DataFrame (final_df_chennai):
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV  20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans  20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV  30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback  59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback  50,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1414   0  Petrol  Hatchback  42,891    Automatic        1  1st Owner
# 1415   0  Diesel        SUV  59,100       Manual        1  1st Owner
# 1416   0  Petrol        SUV  55,913    Automatic        1  1st Owner
# 1417   0  Diesel        SUV  65,000    Automatic        1  1st Owner
# 1418   0  Diesel      Sedan  60,000    Automatic        1  1st Owner
#
#              oem              model  modelYear  ...  Remote Climate Control  \
# ...

# %%
# Assuming final_df_chennai is already defined

# Specify the file name
file_name = "final_df_chennai.xlsx"

# Save the DataFrame to an Excel file
final_df_chennai.to_excel(file_name, index=False)

print(f"DataFrame has been saved to {file_name}")
# Out:
# DataFrame has been saved to final_df_chennai.xlsx

# %%
########################################################################################################################################################

# %% [markdown]
# ## Banglore :

# %%
import pandas as pd
import ast  # Use ast for safer evaluation of strings to dictionaries

# Step 1: Load your DataFrame from the Excel file
file_path = 'bangalore_cars.xlsx'  # Your Excel file name
df = pd.read_excel(file_path)

# Step 2: Initialize an empty list to hold the structured data
unwound_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    # Initialize a dictionary for the current row
    combined_data = {}
    
    # Specify the columns containing dictionaries
    dict_columns = ['new_car_detail', 'new_car_overview', 'new_car_feature', 'new_car_specs']
    
    # Step 4: Extract and merge dictionaries from the specified columns
    for col in dict_columns:
        try:
            # Safely convert the string representation of the dictionary to an actual dictionary
            dict_value = ast.literal_eval(row[col])  
            if isinstance(dict_value, dict):
                combined_data.update(dict_value)  # Merge the extracted dictionary
        except Exception as e:
            print(f"Error parsing row {index}, column {col}: {e}")

    # Append the combined data for the current row to the unwound data list
    unwound_data.append(combined_data)

# Step 5: Create a DataFrame from the unwound data
unwound_df = pd.DataFrame(unwound_data)

# Optional: Display the unwound DataFrame
print(unwound_df)

# Save the unwound DataFrame to a new Excel file if needed
unwound_df.to_excel('unwound_bangalore_cars.xlsx', index=False)
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner
# 1      0  Petrol        SUV    32,706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback    11,949       Manual        1  1st Owner
# 3      0  Petrol      Sedan    17,794       Manual        1  1st Owner
# 4      0  Diesel        SUV    60,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1476   0  Diesel        SUV  1,56,039       Manual        2  2nd Owner
# 1477   0  Petrol      Sedan    56,000       Manual        2  2nd Owner
# 1478   0  Petrol  Hatchback    42,000       Manual        2  2nd Owner
# 1479   0  Diesel  Hatchback    93,003       Manual        1  1st Owner
# 1480   0  Petrol  Hatchback    36,000    Automatic        2  2nd Owner
#
#           oem               model  modelYear  ...         price priceActual  \
# ...

# %%
import pandas as pd

# Step 1: Read the Excel file
df = pd.read_excel("bangalore_cars.xlsx")

# Step 2: Initialize an empty list to hold structured data
structured_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    row_data = {}
    
    # Convert the string representation of the dictionary to an actual dictionary
    try:
        dict_value = eval(row['new_car_detail'])  # Replace eval with ast.literal_eval for safer evaluation
        if isinstance(dict_value, dict):
            row_data = dict_value
    except Exception as e:
        print(f"Error parsing row {index}: {e}")
        row_data = None

    # Append the row dictionary to the structured data list
    structured_data.append(row_data)

# Step 4: Create a DataFrame from the list of dictionaries in 'new_car_detail'
unwound_df = pd.json_normalize(structured_data)

# Optional: Display the unwound DataFrame
print(unwound_df)

# Save the unwound DataFrame to a new Excel file
#unwound_df.to_excel('unwound_new_car_detail.xlsx', index=False)
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner
# 1      0  Petrol        SUV    32,706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback    11,949       Manual        1  1st Owner
# 3      0  Petrol      Sedan    17,794       Manual        1  1st Owner
# 4      0  Diesel        SUV    60,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1476   0  Diesel        SUV  1,56,039       Manual        2  2nd Owner
# 1477   0  Petrol      Sedan    56,000       Manual        2  2nd Owner
# 1478   0  Petrol  Hatchback    42,000       Manual        2  2nd Owner
# 1479   0  Diesel  Hatchback    93,003       Manual        1  1st Owner
# 1480   0  Petrol  Hatchback    36,000    Automatic        2  2nd Owner
#
#           oem               model  modelYear  centralVariantId  \
# ...

# %%
import pandas as pd

# Step 1: Read the Excel file
df = pd.read_excel("bangalore_cars.xlsx")

# Step 2: Initialize an empty list to hold structured data
structured_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    row_data = {}
    
    # Convert the string representation of the dictionary to an actual dictionary
    try:
        dict_value = eval(row['new_car_overview'])  # Replace eval with ast.literal_eval for safer evaluation
        if isinstance(dict_value, dict):
            row_data = dict_value
    except Exception as e:
        print(f"Error parsing row {index}: {e}")
        row_data = None

    # Append the row dictionary to the structured data list
    structured_data.append(row_data)

# Step 4: Create a DataFrame from the list of dictionaries in 'new_car_detail'
unwound_df1 = pd.json_normalize(structured_data)

# Optional: Display the unwound DataFrame
print(unwound_df1)

# Save the unwound DataFrame to a new Excel file
#unwound_df.to_excel('unwound_new_car_detail.xlsx', index=False)
# Out:
#            heading                                                top  \
# 0     Car overview  [{'key': 'Registration Year', 'value': '2015',...
# 1     Car overview  [{'key': 'Registration Year', 'value': 'Feb 20...
# 2     Car overview  [{'key': 'Registration Year', 'value': 'Sept 2...
# 3     Car overview  [{'key': 'Registration Year', 'value': 'Dec 20...
# 4     Car overview  [{'key': 'Registration Year', 'value': '2015',...
# ...            ...                                                ...
# 1476  Car overview  [{'key': 'Registration Year', 'value': 'May 20...
# 1477  Car overview  [{'key': 'Registration Year', 'value': 'Jun 20...
# 1478  Car overview  [{'key': 'Registration Year', 'value': 'Sept 2...
# 1479  Car overview  [{'key': 'Registration Year', 'value': 'Dec 20...
# 1480  Car overview  [{'key': 'Registration Year', 'value': 'May 20...
#
#      bottomData
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# ...         ...
# ...

# %%
import pandas as pd

# Step 1: Read the Excel file
df = pd.read_excel("bangalore_cars.xlsx")

# Step 2: Initialize an empty list to hold structured data
structured_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    row_data = {}
    
    # Convert the string representation of the dictionary to an actual dictionary
    try:
        dict_value = eval(row['new_car_feature'])  # Replace eval with ast.literal_eval for safer evaluation
        if isinstance(dict_value, dict):
            row_data = dict_value
    except Exception as e:
        print(f"Error parsing row {index}: {e}")
        row_data = None

    # Append the row dictionary to the structured data list
    structured_data.append(row_data)

# Step 4: Create a DataFrame from the list of dictionaries in 'new_car_detail'
unwound_df2 = pd.json_normalize(structured_data)

# Optional: Display the unwound DataFrame
print(unwound_df2)

# Save the unwound DataFrame to a new Excel file
#unwound_df.to_excel('unwound_new_car_detail.xlsx', index=False)
# Out:
#        heading                                                top  \
# 0     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 2     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 3     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 4     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# ...        ...                                                ...
# 1476  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1477  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1478  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1479  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1480  Features  [{'value': 'Power Steering'}, {'value': 'Power...
#
#                                                    data  \
# 0     [{'heading': 'Comfort & Convenience', 'subHead...
# 1     [{'heading': 'Comfort & Convenience', 'subHead...
# ...

# %%
import pandas as pd

# Step 1: Read the Excel file
df = pd.read_excel("bangalore_cars.xlsx")

# Step 2: Initialize an empty list to hold structured data
structured_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    row_data = {}
    
    # Convert the string representation of the dictionary to an actual dictionary
    try:
        dict_value = eval(row['new_car_specs'])  # Replace eval with ast.literal_eval for safer evaluation
        if isinstance(dict_value, dict):
            row_data = dict_value
    except Exception as e:
        print(f"Error parsing row {index}: {e}")
        row_data = None

    # Append the row dictionary to the structured data list
    structured_data.append(row_data)

# Step 4: Create a DataFrame from the list of dictionaries in 'new_car_detail'
unwound_df3 = pd.json_normalize(structured_data)

# Optional: Display the unwound DataFrame
print(unwound_df3)

# Save the unwound DataFrame to a new Excel file
#unwound_df.to_excel('unwound_new_car_detail.xlsx', index=False)
# Out:
#              heading                                                top  \
# 0     Specifications  [{'key': 'Mileage', 'value': '23.1 kmpl'}, {'k...
# 1     Specifications  [{'key': 'Mileage', 'value': '17 kmpl'}, {'key...
# 2     Specifications  [{'key': 'Mileage', 'value': '23.84 kmpl'}, {'...
# 3     Specifications  [{'key': 'Mileage', 'value': '19.1 kmpl'}, {'k...
# 4     Specifications  [{'key': 'Mileage', 'value': '23.65 kmpl'}, {'...
# ...              ...                                                ...
# 1476  Specifications  [{'key': 'Mileage', 'value': '12.55 kmpl'}, {'...
# 1477  Specifications  [{'key': 'Mileage', 'value': '15 kmpl'}, {'key...
# 1478  Specifications  [{'key': 'Mileage', 'value': '19.4 kmpl'}, {'k...
# 1479  Specifications  [{'key': 'Mileage', 'value': '22.54 kmpl'}, {'...
# 1480  Specifications  [{'key': 'Mileage', 'value': '18.9 kmpl'}, {'k...
#
#                                                    data commonIcon
# ...

# %%
import pandas as pd

# Assume df1, df2, df3, and df4 are your four DataFrames

# Concatenate the DataFrames column-wise
combined_df = pd.concat([unwound_df, unwound_df1, unwound_df2, unwound_df3], axis=1)

# Optional: Display the combined DataFrame
print(combined_df)

# Save the combined DataFrame to a new Excel file if needed
combined_df.to_excel('combined_data_column_wise_bangalore.xlsx', index=False)
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner
# 1      0  Petrol        SUV    32,706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback    11,949       Manual        1  1st Owner
# 3      0  Petrol      Sedan    17,794       Manual        1  1st Owner
# 4      0  Diesel        SUV    60,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1476   0  Diesel        SUV  1,56,039       Manual        2  2nd Owner
# 1477   0  Petrol      Sedan    56,000       Manual        2  2nd Owner
# 1478   0  Petrol  Hatchback    42,000       Manual        2  2nd Owner
# 1479   0  Diesel  Hatchback    93,003       Manual        1  1st Owner
# 1480   0  Petrol  Hatchback    36,000    Automatic        2  2nd Owner
#
#           oem               model  modelYear  ...  \
# 0      Maruti      Maruti Celerio       2015  ...
# ...

# %%
import pandas as pd

# Example DataFrame with repeating columns (for demonstration purposes)
# combined_df = pd.DataFrame(...)  # Assume this is your existing DataFrame

# Step 1: Get the current column names
original_columns = combined_df.columns

# Step 2: Create a new list to hold unique column names
new_columns = []
column_count = {}

# Step 3: Loop through original columns and create unique names
for col in original_columns:
    if col in column_count:
        column_count[col] += 1
        new_columns.append(f"{col}_{column_count[col]}")  # Append count as suffix
    else:
        column_count[col] = 1
        new_columns.append(col)  # Keep original name for the first occurrence

# Step 4: Assign the new column names to the DataFrame
combined_df.columns = new_columns

# Optional: Display the updated DataFrame columns
print(combined_df.columns)
# Out:
# Index(['it', 'ft', 'bt', 'km', 'transmission', 'ownerNo', 'owner', 'oem',
#        'model', 'modelYear', 'centralVariantId', 'variantName', 'price',
#        'priceActual', 'priceSaving', 'priceFixedText', 'trendingText.imgUrl',
#        'trendingText.heading', 'trendingText.desc', 'heading', 'top',
#        'bottomData', 'heading_2', 'top_2', 'data', 'commonIcon', 'heading_3',
#        'top_3', 'data_2', 'commonIcon_2'],
#       dtype='object')

# %%
import pandas as pd

# Function to extract and convert 'top1' into a DataFrame
def extract_top_to_dataframe(main_df):
    rows = []  # To hold the extracted data
    
    # Loop through each row in the main DataFrame
    for _, row in main_df.iterrows():
        top3_data = row['top_3']  # Access the list directly
        
        # Check if the top1_data is a list
        if isinstance(top3_data, list):
            # Create a dictionary from the extracted key-value pairs
            row_dict = {item['key']: item['value'] for item in top3_data if 'key' in item and 'value' in item}
            rows.append(row_dict)  # Add the dictionary to the rows list
        else:
            print(f"Unexpected format for row: {row}. Expected a list but got {type(top3_data)}")
    
    # Create a new DataFrame from the rows list
    top3_df = pd.DataFrame(rows)
    return top3_df

# Extracting the DataFrame from 'top1'
top3_df = extract_top_to_dataframe(combined_df)

# Display the new DataFrame
print(top3_df)
# Out:
#          Mileage   Engine  Max Power    Torque Seats Wheel Size
# 0      23.1 kmpl   998 CC   67.04bhp      90Nm     5        NaN
# 1        17 kmpl  1497 CC  121.31bhp     150Nm     5         16
# 2     23.84 kmpl  1199 CC      84bhp     114Nm     5         14
# 3      19.1 kmpl  1197 CC   81.86bhp  113.75Nm     5         14
# 4     23.65 kmpl  1248 CC    88.5bhp     200Nm     5         16
# ...          ...      ...        ...       ...   ...        ...
# 1476  12.55 kmpl  2982 CC   168.5bhp     343Nm     7         17
# 1477     15 kmpl  1586 CC     104.68       145     5         16
# 1478   19.4 kmpl  1198 CC    86.8bhp     109Nm     5        NaN
# 1479  22.54 kmpl  1396 CC   88.73bhp   219.7Nm     5         16
# 1480   18.9 kmpl  1197 CC      82bhp     114Nm     5         14
#
# [1481 rows x 6 columns]

# %%
import pandas as pd

# Assuming combined_df is your existing DataFrame with a column named 'top_2'
# combined_df = ...  # Your existing DataFrame

def extract_list_of_dicts_to_dataframe(main_df, column_name):
    # Initialize a list to store the extracted data
    extracted_data = []

    for index, row in main_df.iterrows():
        # Check if the cell is a list and not empty
        if isinstance(row[column_name], list) and row[column_name]:
            # Create a dictionary from the extracted values
            row_dict = {item['value']: True for item in row[column_name]}
        else:
            row_dict = {}

        extracted_data.append(row_dict)

    # Create a DataFrame from the extracted data
    extracted_df = pd.DataFrame(extracted_data)

    return extracted_df

# Extract DataFrame for top_2
top_2_df = extract_list_of_dicts_to_dataframe(combined_df, 'top_2')

# Display the DataFrame
print("DataFrame for top_2:")
print(top_2_df)
# Out:
# DataFrame for top_2:
#      Power Steering Power Windows Front Air Conditioner Heater  \
# 0              True                True            True   True
# 1              True                True            True   True
# 2              True                True            True   True
# 3              True                True            True   True
# 4              True                True            True   True
# ...             ...                 ...             ...    ...
# 1476           True                True            True   True
# 1477           True                True            True   True
# 1478           True                True            True   True
# 1479           True                True            True   True
# 1480           True                True            True   True
#
#      Adjustable Head Lights Manually Adjustable Exterior Rear View Mirror  \
# 0                      True                                          True
# ...

# %%
import pandas as pd

# Function to extract and convert 'top1' into a DataFrame
def extract_top_to_dataframe(main_df):
    rows = []  # To hold the extracted data
    
    # Loop through each row in the main DataFrame
    for _, row in main_df.iterrows():
        top_data = row['top']  # Access the list directly
        
        # Check if the top1_data is a list
        if isinstance(top_data, list):
            # Create a dictionary from the extracted key-value pairs
            row_dict = {item['key']: item['value'] for item in top_data if 'key' in item and 'value' in item}
            rows.append(row_dict)  # Add the dictionary to the rows list
        else:
            print(f"Unexpected format for row: {row}. Expected a list but got {type(top_data)}")
    
    # Create a new DataFrame from the rows list
    top_df = pd.DataFrame(rows)
    return top_df

# Extracting the DataFrame from 'top1'
top_df = extract_top_to_dataframe(combined_df)

# Display the new DataFrame
print(top_df)
# Out:
#      Registration Year     Insurance Validity Fuel Type    Seats  \
# 0                 2015  Third Party insurance    Petrol  5 Seats
# 1             Feb 2018          Comprehensive    Petrol  5 Seats
# 2            Sept 2018          Comprehensive    Petrol  5 Seats
# 3             Dec 2014          Comprehensive    Petrol  5 Seats
# 4                 2015  Third Party insurance    Diesel  5 Seats
# ...                ...                    ...       ...      ...
# 1476          May 2012          Comprehensive    Diesel  7 Seats
# 1477          Jun 2008  Third Party insurance    Petrol  5 Seats
# 1478         Sept 2014          Comprehensive    Petrol  5 Seats
# 1479          Dec 2018          Comprehensive    Diesel  5 Seats
# 1480          May 2017          Comprehensive    Petrol  5 Seats
#
#         Kms Driven   RTO     Ownership Engine Displacement Transmission  \
# 0     1,20,000 Kms  KA51   Third Owner              998 cc       Manual
# ...

# %%
import pandas as pd

def extract_data_to_dataframe(main_df, column_name):
    # Create a list to hold the rows for the new DataFrame
    data_rows = []
    
    # Iterate over each row in the main DataFrame
    for index, row in main_df.iterrows():
        # Check if the cell is a list and contains dictionaries
        if isinstance(row[column_name], list) and row[column_name]:
            # Extract the 'list' field from the first dictionary in the row
            list_values = row[column_name][0].get('list', [])
            # Create a dictionary to hold values for this row
            row_dict = {item['value']: True for item in list_values}
            # Append the dictionary to the rows list
            data_rows.append(row_dict)
        else:
            # If there's no data, append an empty dictionary
            data_rows.append({})

    # Create a DataFrame from the list of dictionaries
    data_df = pd.DataFrame(data_rows)

    return data_df

# Extract DataFrame for the 'data' column
data_df = extract_data_to_dataframe(combined_df, 'data')

# Display the DataFrame
print("DataFrame for data:")
print(data_df)
# Out:
# DataFrame for data:
#      Power Steering Power Windows Front Power Windows Rear  \
# 0              True                True               True
# 1              True                True               True
# 2              True                True               True
# 3              True                True               True
# 4              True                True               True
# ...             ...                 ...                ...
# 1476           True                True               True
# 1477           True                True               True
# 1478           True                True               True
# 1479           True                True               True
# 1480           True                True               True
#
#      Remote Trunk Opener Remote Fuel Lid Opener Low Fuel Warning Light  \
# 0                   True                   True                   True
# 1                   True                   True                   True
# ...

# %%
import pandas as pd

def extract_data2_to_dataframe(main_df, column_name):
    # Create a list to hold the rows for the new DataFrame
    data_rows = []
    
    # Iterate over each row in the main DataFrame
    for index, row in main_df.iterrows():
        # Check if the cell is a list and contains dictionaries
        if isinstance(row[column_name], list) and row[column_name]:
            # Create a dictionary to hold values for this row
            row_dict = {}
            for section in row[column_name]:
                # Extract the 'list' field from each section
                for item in section.get('list', []):
                    # Use the 'key' as the column name and 'value' as the value
                    row_dict[item['key']] = item['value']
            # Append the dictionary to the rows list
            data_rows.append(row_dict)
        else:
            # If there's no data, append an empty dictionary
            data_rows.append({})

    # Create a DataFrame from the list of dictionaries
    data2_df = pd.DataFrame(data_rows)

    return data2_df

# Extract DataFrame for the 'data_2' column
data2_df = extract_data2_to_dataframe(combined_df, 'data_2')

# Display the DataFrame
print("DataFrame for data_2:")
print(data2_df)
# Out:
# DataFrame for data_2:
#        Color               Engine Type Displacement              Max Power  \
# 0      White               K10B Engine          998       67.04bhp@6000rpm
# 1      White      Ti-VCT Petrol Engine         1497      121.31bhp@6500rpm
# 2        Red           Revotron Engine         1199          84bhp@6000rpm
# 3     Others  Kappa VTVT Petrol Engine         1197       81.86bhp@6000rpm
# 4       Gray    DDiS 200 Diesel Engine         1248        88.5bhp@4000rpm
# ...      ...                       ...          ...                    ...
# 1476    Blue        D-4D Diesel Engine         2982       168.5bhp@3600rpm
# 1477     Red            In-Line Engine         1586  104.68@5,600 (PS@rpm)
# 1478   White             i-VTEC Engine         1198        86.8bhp@6000rpm
# 1479     Red     U2 CRDI Diesel Engine         1396       88.73bhp@4000rpm
# 1480   White  Kappa VTVT Petrol Engine         1197          82bhp@6000rpm
#
# ...

# %%
import pandas as pd

# Assuming combined_df, top_df, top3_df, data2_df, top_2_df, data_df are already defined

# Concatenate the DataFrames column-wise
final_df_bangalore = pd.concat([combined_df, top_df, top3_df, data2_df, top_2_df, data_df], axis=1)

# Display the final DataFrame
print("Final DataFrame (final_df_bangalore):")
print(final_df_bangalore)
# Out:
# Final DataFrame (final_df_bangalore):
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner
# 1      0  Petrol        SUV    32,706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback    11,949       Manual        1  1st Owner
# 3      0  Petrol      Sedan    17,794       Manual        1  1st Owner
# 4      0  Diesel        SUV    60,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1476   0  Diesel        SUV  1,56,039       Manual        2  2nd Owner
# 1477   0  Petrol      Sedan    56,000       Manual        2  2nd Owner
# 1478   0  Petrol  Hatchback    42,000       Manual        2  2nd Owner
# 1479   0  Diesel  Hatchback    93,003       Manual        1  1st Owner
# 1480   0  Petrol  Hatchback    36,000    Automatic        2  2nd Owner
#
#           oem               model  modelYear  ...  Hands Free Tailgate  \
# ...

# %%
## # Assuming final_df_chennai is already defined

# Specify the file name
file_name = "final_df_bangalore.xlsx"

# Save the DataFrame to an Excel file
final_df_bangalore.to_excel(file_name, index=False)

print(f"DataFrame has been saved to {file_name}")
# Out:
# DataFrame has been saved to final_df_bangalore.xlsx

# %% [markdown]
# ## Delhi

# %%
import pandas as pd
import ast  # Use ast for safer evaluation of strings to dictionaries

# Step 1: Load your DataFrame from the Excel file
file_path = 'delhi_cars.xlsx'  # Your Excel file name
df = pd.read_excel(file_path)

# Step 2: Initialize an empty list to hold the structured data
unwound_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    # Initialize a dictionary for the current row
    combined_data = {}
    
    # Specify the columns containing dictionaries
    dict_columns = ['new_car_detail', 'new_car_overview', 'new_car_feature', 'new_car_specs']
    
    # Step 4: Extract and merge dictionaries from the specified columns
    for col in dict_columns:
        try:
            # Safely convert the string representation of the dictionary to an actual dictionary
            dict_value = ast.literal_eval(row[col])  
            if isinstance(dict_value, dict):
                combined_data.update(dict_value)  # Merge the extracted dictionary
        except Exception as e:
            print(f"Error parsing row {index}, column {col}: {e}")

    # Append the combined data for the current row to the unwound data list
    unwound_data.append(combined_data)

# Step 5: Create a DataFrame from the unwound data
unwound_df = pd.DataFrame(unwound_data)

# Optional: Display the unwound DataFrame
print(unwound_df)

# Save the unwound DataFrame to a new Excel file if needed
#unwound_df.to_excel('unwound_bangalore_cars.xlsx', index=False)
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Diesel        SUV  10,000    Automatic        1  1st Owner
# 1      0  Petrol        SUV  57,437       Manual        2  2nd Owner
# 2      0  Petrol        SUV   8,000    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback  28,151       Manual        2  2nd Owner
# 4      0  Petrol        SUV  60,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1480   0  Petrol      Sedan  60,000    Automatic        1  1st Owner
# 1481   0  Petrol        SUV  20,000       Manual        1  1st Owner
# 1482   0  Petrol      Sedan  60,000       Manual        1  1st Owner
# 1483   0  Diesel        SUV  38,000       Manual        1  1st Owner
# 1484   0  Diesel        SUV   7,000    Automatic        0  0th Owner
#
#                 oem              model  modelYear  ...         price  \
# ...

# %%
import pandas as pd

# Step 1: Read the Excel file
df = pd.read_excel("delhi_cars.xlsx")

# Step 2: Initialize an empty list to hold structured data
structured_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    row_data = {}
    
    # Convert the string representation of the dictionary to an actual dictionary
    try:
        dict_value = eval(row['new_car_detail'])  # Replace eval with ast.literal_eval for safer evaluation
        if isinstance(dict_value, dict):
            row_data = dict_value
    except Exception as e:
        print(f"Error parsing row {index}: {e}")
        row_data = None

    # Append the row dictionary to the structured data list
    structured_data.append(row_data)

# Step 4: Create a DataFrame from the list of dictionaries in 'new_car_detail'
unwound_df = pd.json_normalize(structured_data)

# Optional: Display the unwound DataFrame
print(unwound_df)

# Save the unwound DataFrame to a new Excel file
#unwound_df.to_excel('unwound_new_car_detail.xlsx', index=False)
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Diesel        SUV  10,000    Automatic        1  1st Owner
# 1      0  Petrol        SUV  57,437       Manual        2  2nd Owner
# 2      0  Petrol        SUV   8,000    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback  28,151       Manual        2  2nd Owner
# 4      0  Petrol        SUV  60,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1480   0  Petrol      Sedan  60,000    Automatic        1  1st Owner
# 1481   0  Petrol        SUV  20,000       Manual        1  1st Owner
# 1482   0  Petrol      Sedan  60,000       Manual        1  1st Owner
# 1483   0  Diesel        SUV  38,000       Manual        1  1st Owner
# 1484   0  Diesel        SUV   7,000    Automatic        0  0th Owner
#
#                 oem              model  modelYear  centralVariantId  \
# 0               Kia         Kia Seltos       2022              7121
# ...

# %%
import pandas as pd

# Step 1: Read the Excel file
df = pd.read_excel("delhi_cars.xlsx")

# Step 2: Initialize an empty list to hold structured data
structured_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    row_data = {}
    
    # Convert the string representation of the dictionary to an actual dictionary
    try:
        dict_value = eval(row['new_car_overview'])  # Replace eval with ast.literal_eval for safer evaluation
        if isinstance(dict_value, dict):
            row_data = dict_value
    except Exception as e:
        print(f"Error parsing row {index}: {e}")
        row_data = None

    # Append the row dictionary to the structured data list
    structured_data.append(row_data)

# Step 4: Create a DataFrame from the list of dictionaries in 'new_car_detail'
unwound_df1 = pd.json_normalize(structured_data)

# Optional: Display the unwound DataFrame
print(unwound_df1)

# Save the unwound DataFrame to a new Excel file
#unwound_df.to_excel('unwound_new_car_detail.xlsx', index=False)
# Out:
#            heading                                                top  \
# 0     Car overview  [{'key': 'Registration Year', 'value': '2022',...
# 1     Car overview  [{'key': 'Registration Year', 'value': 'May 20...
# 2     Car overview  [{'key': 'Registration Year', 'value': 'Dec 20...
# 3     Car overview  [{'key': 'Registration Year', 'value': 'Jan 20...
# 4     Car overview  [{'key': 'Registration Year', 'value': '2017',...
# ...            ...                                                ...
# 1480  Car overview  [{'key': 'Registration Year', 'value': '2019',...
# 1481  Car overview  [{'key': 'Registration Year', 'value': '2021',...
# 1482  Car overview  [{'key': 'Registration Year', 'value': '2011',...
# 1483  Car overview  [{'key': 'Registration Year', 'value': 'Oct 20...
# 1484  Car overview  [{'key': 'Insurance Validity', 'value': 'Third...
#
#      bottomData
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# ...         ...
# ...

# %%
import pandas as pd

# Step 1: Read the Excel file
df = pd.read_excel("delhi_cars.xlsx")

# Step 2: Initialize an empty list to hold structured data
structured_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    row_data = {}
    
    # Convert the string representation of the dictionary to an actual dictionary
    try:
        dict_value = eval(row['new_car_feature'])  # Replace eval with ast.literal_eval for safer evaluation
        if isinstance(dict_value, dict):
            row_data = dict_value
    except Exception as e:
        print(f"Error parsing row {index}: {e}")
        row_data = None

    # Append the row dictionary to the structured data list
    structured_data.append(row_data)

# Step 4: Create a DataFrame from the list of dictionaries in 'new_car_detail'
unwound_df2 = pd.json_normalize(structured_data)

# Optional: Display the unwound DataFrame
print(unwound_df2)

# Save the unwound DataFrame to a new Excel file
#unwound_df.to_excel('unwound_new_car_detail.xlsx', index=False)
# Out:
#        heading                                                top  \
# 0     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 2     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 3     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 4     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# ...        ...                                                ...
# 1480  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1481  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1482  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1483  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1484  Features  [{'value': 'Power Steering'}, {'value': 'Power...
#
#                                                    data  \
# 0     [{'heading': 'Comfort & Convenience', 'subHead...
# 1     [{'heading': 'Comfort & Convenience', 'subHead...
# ...

# %%
import pandas as pd

# Step 1: Read the Excel file
df = pd.read_excel("delhi_cars.xlsx")

# Step 2: Initialize an empty list to hold structured data
structured_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    row_data = {}
    
    # Convert the string representation of the dictionary to an actual dictionary
    try:
        dict_value = eval(row['new_car_specs'])  # Replace eval with ast.literal_eval for safer evaluation
        if isinstance(dict_value, dict):
            row_data = dict_value
    except Exception as e:
        print(f"Error parsing row {index}: {e}")
        row_data = None

    # Append the row dictionary to the structured data list
    structured_data.append(row_data)

# Step 4: Create a DataFrame from the list of dictionaries in 'new_car_detail'
unwound_df3 = pd.json_normalize(structured_data)

# Optional: Display the unwound DataFrame
print(unwound_df3)

# Save the unwound DataFrame to a new Excel file
#unwound_df.to_excel('unwound_new_car_detail.xlsx', index=False)
# Out:
#              heading                                                top  \
# 0     Specifications  [{'key': 'Mileage', 'value': '18 kmpl'}, {'key...
# 1     Specifications  [{'key': 'Mileage', 'value': '15.29 kmpl'}, {'...
# 2     Specifications  [{'key': 'Mileage', 'value': '12.74 kmpl'}, {'...
# 3     Specifications  [{'key': 'Mileage', 'value': '22.38 kmpl'}, {'...
# 4     Specifications  [{'key': 'Mileage', 'value': '15.29 kmpl'}, {'...
# ...              ...                                                ...
# 1480  Specifications  [{'key': 'Mileage', 'value': '18 kmpl'}, {'key...
# 1481  Specifications  [{'key': 'Mileage', 'value': '18.4 kmpl'}, {'k...
# 1482  Specifications  [{'key': 'Mileage', 'value': '17.01 kmpl'}, {'...
# 1483  Specifications  [{'key': 'Mileage', 'value': '20.5 kmpl'}, {'k...
# 1484  Specifications  [{'key': 'Mileage', 'value': '12.04 kmpl'}, {'...
#
#                                                    data commonIcon
# ...

# %%
import pandas as pd

# Assume df1, df2, df3, and df4 are your four DataFrames

# Concatenate the DataFrames column-wise
combined_df = pd.concat([unwound_df, unwound_df1, unwound_df2, unwound_df3], axis=1)

# Optional: Display the combined DataFrame
print(combined_df)

# Save the combined DataFrame to a new Excel file if needed
combined_df.to_excel('combined_data_column_wise_delhi.xlsx', index=False)
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Diesel        SUV  10,000    Automatic        1  1st Owner
# 1      0  Petrol        SUV  57,437       Manual        2  2nd Owner
# 2      0  Petrol        SUV   8,000    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback  28,151       Manual        2  2nd Owner
# 4      0  Petrol        SUV  60,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1480   0  Petrol      Sedan  60,000    Automatic        1  1st Owner
# 1481   0  Petrol        SUV  20,000       Manual        1  1st Owner
# 1482   0  Petrol      Sedan  60,000       Manual        1  1st Owner
# 1483   0  Diesel        SUV  38,000       Manual        1  1st Owner
# 1484   0  Diesel        SUV   7,000    Automatic        0  0th Owner
#
#                 oem              model  modelYear  ...  \
# 0               Kia         Kia Seltos       2022  ...
# ...

# %%
import pandas as pd

# Example DataFrame with repeating columns (for demonstration purposes)
# combined_df = pd.DataFrame(...)  # Assume this is your existing DataFrame

# Step 1: Get the current column names
original_columns = combined_df.columns

# Step 2: Create a new list to hold unique column names
new_columns = []
column_count = {}

# Step 3: Loop through original columns and create unique names
for col in original_columns:
    if col in column_count:
        column_count[col] += 1
        new_columns.append(f"{col}_{column_count[col]}")  # Append count as suffix
    else:
        column_count[col] = 1
        new_columns.append(col)  # Keep original name for the first occurrence

# Step 4: Assign the new column names to the DataFrame
combined_df.columns = new_columns

# Optional: Display the updated DataFrame columns
print(combined_df.columns)
# Out:
# Index(['it', 'ft', 'bt', 'km', 'transmission', 'ownerNo', 'owner', 'oem',
#        'model', 'modelYear', 'centralVariantId', 'variantName', 'price',
#        'priceActual', 'priceSaving', 'priceFixedText', 'trendingText.imgUrl',
#        'trendingText.heading', 'trendingText.desc', 'heading', 'top',
#        'bottomData', 'heading_2', 'top_2', 'data', 'commonIcon', 'heading_3',
#        'top_3', 'data_2', 'commonIcon_2'],
#       dtype='object')

# %%
import pandas as pd

# Function to extract and convert 'top1' into a DataFrame
def extract_top_to_dataframe(main_df):
    rows = []  # To hold the extracted data
    
    # Loop through each row in the main DataFrame
    for _, row in main_df.iterrows():
        top3_data = row['top_3']  # Access the list directly
        
        # Check if the top1_data is a list
        if isinstance(top3_data, list):
            # Create a dictionary from the extracted key-value pairs
            row_dict = {item['key']: item['value'] for item in top3_data if 'key' in item and 'value' in item}
            rows.append(row_dict)  # Add the dictionary to the rows list
        else:
            print(f"Unexpected format for row: {row}. Expected a list but got {type(top3_data)}")
    
    # Create a new DataFrame from the rows list
    top3_df = pd.DataFrame(rows)
    return top3_df

# Extracting the DataFrame from 'top1'
top3_df = extract_top_to_dataframe(combined_df)

# Display the new DataFrame
print(top3_df)
# Out:
#          Mileage   Engine  Max Power    Torque Wheel Size Seats
# 0        18 kmpl  1493 CC  113.43bhp     250Nm         17     5
# 1     15.29 kmpl  1591 CC   121.3bhp     151Nm        NaN     5
# 2     12.74 kmpl  1991 CC     197bhp     320nm         19     5
# 3     22.38 kmpl  1197 CC   88.50bhp     113Nm        NaN     5
# 4     15.29 kmpl  1591 CC   121.3bhp     151Nm        NaN     5
# ...          ...      ...        ...       ...        ...   ...
# 1480     18 kmpl  1497 CC   117.6bhp     145Nm         15     5
# 1481   18.4 kmpl  1197 CC   81.86bhp     115Nm        NaN     5
# 1482  17.01 kmpl  1591 CC   121.3bhp   154.9Nm         16     5
# 1483   20.5 kmpl  1582 CC   126.2bhp  259.87NM         17     5
# 1484  12.04 kmpl  1996 CC  212.55bhp   478.5Nm         19     6
#
# [1485 rows x 6 columns]

# %%
import pandas as pd

# Assuming combined_df is your existing DataFrame with a column named 'top_2'
# combined_df = ...  # Your existing DataFrame

def extract_list_of_dicts_to_dataframe(main_df, column_name):
    # Initialize a list to store the extracted data
    extracted_data = []

    for index, row in main_df.iterrows():
        # Check if the cell is a list and not empty
        if isinstance(row[column_name], list) and row[column_name]:
            # Create a dictionary from the extracted values
            row_dict = {item['value']: True for item in row[column_name]}
        else:
            row_dict = {}

        extracted_data.append(row_dict)

    # Create a DataFrame from the extracted data
    extracted_df = pd.DataFrame(extracted_data)

    return extracted_df

# Extract DataFrame for top_2
top_2_df = extract_list_of_dicts_to_dataframe(combined_df, 'top_2')

# Display the DataFrame
print("DataFrame for top_2:")
print(top_2_df)
# Out:
# DataFrame for top_2:
#      Power Steering Power Windows Front Air Conditioner Heater  \
# 0              True                True            True   True
# 1              True                True            True   True
# 2              True                True            True   True
# 3              True                True            True   True
# 4              True                True            True   True
# ...             ...                 ...             ...    ...
# 1480           True                True            True   True
# 1481           True                True            True   True
# 1482           True                True            True   True
# 1483           True                True            True   True
# 1484           True                True            True   True
#
#      Adjustable Head Lights Fog Lights Front Anti Lock Braking System  \
# 0                      True             True                     True
# ...

# %%
import pandas as pd

# Function to extract and convert 'top1' into a DataFrame
def extract_top_to_dataframe(main_df):
    rows = []  # To hold the extracted data
    
    # Loop through each row in the main DataFrame
    for _, row in main_df.iterrows():
        top_data = row['top']  # Access the list directly
        
        # Check if the top1_data is a list
        if isinstance(top_data, list):
            # Create a dictionary from the extracted key-value pairs
            row_dict = {item['key']: item['value'] for item in top_data if 'key' in item and 'value' in item}
            rows.append(row_dict)  # Add the dictionary to the rows list
        else:
            print(f"Unexpected format for row: {row}. Expected a list but got {type(top_data)}")
    
    # Create a new DataFrame from the rows list
    top_df = pd.DataFrame(rows)
    return top_df

# Extracting the DataFrame from 'top1'
top_df = extract_top_to_dataframe(combined_df)

# Display the new DataFrame
print(top_df)
# Out:
#      Registration Year     Insurance Validity Fuel Type    Seats  Kms Driven  \
# 0                 2022  Third Party insurance    Diesel  5 Seats  10,000 Kms
# 1             May 2016               Zero Dep    Petrol  5 Seats  57,437 Kms
# 2             Dec 2020          Comprehensive    Petrol  5 Seats   8,000 Kms
# 3             Jan 2019          Comprehensive    Petrol  5 Seats  28,151 Kms
# 4                 2017  Third Party insurance    Petrol  5 Seats  60,000 Kms
# ...                ...                    ...       ...      ...         ...
# 1480              2019  Third Party insurance    Petrol  5 Seats  60,000 Kms
# 1481              2021  Third Party insurance    Petrol  5 Seats  20,000 Kms
# 1482              2011  Third Party insurance    Petrol  5 Seats  60,000 Kms
# 1483          Oct 2019  Third Party insurance    Diesel  5 Seats  38,000 Kms
# 1484               NaN  Third Party insurance    Diesel  6 Seats   7,000 Kms
#
# ...

# %%
import pandas as pd

def extract_data_to_dataframe(main_df, column_name):
    # Create a list to hold the rows for the new DataFrame
    data_rows = []
    
    # Iterate over each row in the main DataFrame
    for index, row in main_df.iterrows():
        # Check if the cell is a list and contains dictionaries
        if isinstance(row[column_name], list) and row[column_name]:
            # Extract the 'list' field from the first dictionary in the row
            list_values = row[column_name][0].get('list', [])
            # Create a dictionary to hold values for this row
            row_dict = {item['value']: True for item in list_values}
            # Append the dictionary to the rows list
            data_rows.append(row_dict)
        else:
            # If there's no data, append an empty dictionary
            data_rows.append({})

    # Create a DataFrame from the list of dictionaries
    data_df = pd.DataFrame(data_rows)

    return data_df

# Extract DataFrame for the 'data' column
data_df = extract_data_to_dataframe(combined_df, 'data')

# Display the DataFrame
print("DataFrame for data:")
print(data_df)
# Out:
# DataFrame for data:
#      Power Steering Power Windows Front Power Windows Rear  \
# 0              True                True               True
# 1              True                True               True
# 2              True                True               True
# 3              True                True               True
# 4              True                True               True
# ...             ...                 ...                ...
# 1480           True                True               True
# 1481           True                True               True
# 1482           True                True               True
# 1483           True                True               True
# 1484           True                True               True
#
#      Air Quality Control Low Fuel Warning Light Accessory Power Outlet  \
# 0                   True                   True                   True
# 1                    NaN                   True                   True
# ...

# %%
import pandas as pd

def extract_data2_to_dataframe(main_df, column_name):
    # Create a list to hold the rows for the new DataFrame
    data_rows = []
    
    # Iterate over each row in the main DataFrame
    for index, row in main_df.iterrows():
        # Check if the cell is a list and contains dictionaries
        if isinstance(row[column_name], list) and row[column_name]:
            # Create a dictionary to hold values for this row
            row_dict = {}
            for section in row[column_name]:
                # Extract the 'list' field from each section
                for item in section.get('list', []):
                    # Use the 'key' as the column name and 'value' as the value
                    row_dict[item['key']] = item['value']
            # Append the dictionary to the rows list
            data_rows.append(row_dict)
        else:
            # If there's no data, append an empty dictionary
            data_rows.append({})

    # Create a DataFrame from the list of dictionaries
    data2_df = pd.DataFrame(data_rows)

    return data2_df

# Extract DataFrame for the 'data_2' column
data2_df = extract_data2_to_dataframe(combined_df, 'data_2')

# Display the DataFrame
print("DataFrame for data_2:")
print(data2_df)
# Out:
# DataFrame for data_2:
#        Color             Engine Type Displacement            Max Power  \
# 0       Gray          1.5 L CRDi VGT         1493    113.43bhp@4000rpm
# 1      White      VTVT Petrol Engine         1591     121.3bhp@6400rpm
# 2       Grey     M 264 petrol engine         1991  197bhp@5500-6100rpm
# 3     Silver       K Series Dual jet         1197     88.50bhp@6000rpm
# 4      White      VTVT Petrol Engine         1591     121.3bhp@6400rpm
# ...      ...                     ...          ...                  ...
# 1480  Others           i VTEC Engine         1497     117.6bhp@6600rpm
# 1481  Others        SMARTSTREAM G1.2         1197     81.86bhp@6000rpm
# 1482  Others      VTVT Petrol Engine         1591     121.3bhp@6300rpm
# 1483  Silver      U2 CRDI VGT Engine         1582     126.2bhp@4000rpm
# 1484    Grey  DIESEL 2.0L TWIN TURBO         1996    212.55bhp@4000rpm
#
#                  Max Torque  No of Cylinder  Values per Cylinder  \
# ...

# %%
import pandas as pd

# Assuming combined_df, top_df, top3_df, data2_df, top_2_df, data_df are already defined

# Concatenate the DataFrames column-wise
final_df_delhi = pd.concat([combined_df, top_df, top3_df, data2_df, top_2_df, data_df], axis=1)

# Display the final DataFrame
print("Final DataFrame (final_df_delhi):")
print(final_df_delhi)
# Out:
# Final DataFrame (final_df_delhi):
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Diesel        SUV  10,000    Automatic        1  1st Owner
# 1      0  Petrol        SUV  57,437       Manual        2  2nd Owner
# 2      0  Petrol        SUV   8,000    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback  28,151       Manual        2  2nd Owner
# 4      0  Petrol        SUV  60,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1480   0  Petrol      Sedan  60,000    Automatic        1  1st Owner
# 1481   0  Petrol        SUV  20,000       Manual        1  1st Owner
# 1482   0  Petrol      Sedan  60,000       Manual        1  1st Owner
# 1483   0  Diesel        SUV  38,000       Manual        1  1st Owner
# 1484   0  Diesel        SUV   7,000    Automatic        0  0th Owner
#
#                 oem              model  modelYear  ...  Power Boot  \
# ...

# %%
## # Assuming final_df_chennai is already defined

# Specify the file name
file_name = "final_df_delhi.xlsx"

# Save the DataFrame to an Excel file
final_df_delhi.to_excel(file_name, index=False)

print(f"DataFrame has been saved to {file_name}")
# Out:
# DataFrame has been saved to final_df_delhi.xlsx

# %% [markdown]
# ## Hyderabad:

# %%
## import pandas as pd
import ast  # Use ast for safer evaluation of strings to dictionaries

# Step 1: Load your DataFrame from the Excel file
file_path = 'hyderabad_cars.xlsx'  # Your Excel file name
df = pd.read_excel(file_path)

# Step 2: Initialize an empty list to hold the structured data
unwound_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    # Initialize a dictionary for the current row
    combined_data = {}
    
    # Specify the columns containing dictionaries
    dict_columns = ['new_car_detail', 'new_car_overview', 'new_car_feature', 'new_car_specs']
    
    # Step 4: Extract and merge dictionaries from the specified columns
    for col in dict_columns:
        try:
            # Safely convert the string representation of the dictionary to an actual dictionary
            dict_value = ast.literal_eval(row[col])  
            if isinstance(dict_value, dict):
                combined_data.update(dict_value)  # Merge the extracted dictionary
        except Exception as e:
            print(f"Error parsing row {index}, column {col}: {e}")

    # Append the combined data for the current row to the unwound data list
    unwound_data.append(combined_data)

# Step 5: Create a DataFrame from the unwound data
unwound_df = pd.DataFrame(unwound_data)

# Optional: Display the unwound DataFrame
print(unwound_df)

# Save the unwound DataFrame to a new Excel file if needed
#unwound_df.to_excel('unwound_bangalore_cars.xlsx', index=False)
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback    20,000    Automatic        1  1st Owner
# 1      0  Petrol  Hatchback    85,582       Manual        2  2nd Owner
# 2      0  Petrol        SUV    10,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback    50,750       Manual        1  1st Owner
# 4      0  Petrol        SUV    10,000    Automatic        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1478   0  Diesel        SUV    60,000       Manual        1  1st Owner
# 1479   0  Diesel      Sedan    50,000    Automatic        1  1st Owner
# 1480   0  Diesel      Sedan  1,20,000    Automatic        3  3rd Owner
# 1481   0  Diesel        SUV    50,000    Automatic        2  2nd Owner
# 1482   0  Diesel        MUV  1,00,000       Manual        1  1st Owner
#
#              oem            model  modelYear  ...         price priceActual  \
# ...

# %%
import pandas as pd

# Step 1: Read the Excel file
df = pd.read_excel("hyderabad_cars.xlsx")

# Step 2: Initialize an empty list to hold structured data
structured_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    row_data = {}
    
    # Convert the string representation of the dictionary to an actual dictionary
    try:
        dict_value = eval(row['new_car_detail'])  # Replace eval with ast.literal_eval for safer evaluation
        if isinstance(dict_value, dict):
            row_data = dict_value
    except Exception as e:
        print(f"Error parsing row {index}: {e}")
        row_data = None

    # Append the row dictionary to the structured data list
    structured_data.append(row_data)

# Step 4: Create a DataFrame from the list of dictionaries in 'new_car_detail'
unwound_df = pd.json_normalize(structured_data)

# Optional: Display the unwound DataFrame
print(unwound_df)

# Save the unwound DataFrame to a new Excel file
#unwound_df.to_excel('unwound_new_car_detail.xlsx', index=False)
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback    20,000    Automatic        1  1st Owner
# 1      0  Petrol  Hatchback    85,582       Manual        2  2nd Owner
# 2      0  Petrol        SUV    10,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback    50,750       Manual        1  1st Owner
# 4      0  Petrol        SUV    10,000    Automatic        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1478   0  Diesel        SUV    60,000       Manual        1  1st Owner
# 1479   0  Diesel      Sedan    50,000    Automatic        1  1st Owner
# 1480   0  Diesel      Sedan  1,20,000    Automatic        3  3rd Owner
# 1481   0  Diesel        SUV    50,000    Automatic        2  2nd Owner
# 1482   0  Diesel        MUV  1,00,000       Manual        1  1st Owner
#
#              oem            model  modelYear  centralVariantId  \
# ...

# %%
import pandas as pd

# Step 1: Read the Excel file
df = pd.read_excel("hyderabad_cars.xlsx")

# Step 2: Initialize an empty list to hold structured data
structured_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    row_data = {}
    
    # Convert the string representation of the dictionary to an actual dictionary
    try:
        dict_value = eval(row['new_car_overview'])  # Replace eval with ast.literal_eval for safer evaluation
        if isinstance(dict_value, dict):
            row_data = dict_value
    except Exception as e:
        print(f"Error parsing row {index}: {e}")
        row_data = None

    # Append the row dictionary to the structured data list
    structured_data.append(row_data)

# Step 4: Create a DataFrame from the list of dictionaries in 'new_car_detail'
unwound_df1 = pd.json_normalize(structured_data)

# Optional: Display the unwound DataFrame
print(unwound_df1)

# Save the unwound DataFrame to a new Excel file
#unwound_df.to_excel('unwound_new_car_detail.xlsx', index=False)
# Out:
#            heading                                                top  \
# 0     Car overview  [{'key': 'Registration Year', 'value': '2022',...
# 1     Car overview  [{'key': 'Registration Year', 'value': 'Oct 20...
# 2     Car overview  [{'key': 'Registration Year', 'value': '2023',...
# 3     Car overview  [{'key': 'Registration Year', 'value': 'Mar 20...
# 4     Car overview  [{'key': 'Registration Year', 'value': '2022',...
# ...            ...                                                ...
# 1478  Car overview  [{'key': 'Registration Year', 'value': '2013',...
# 1479  Car overview  [{'key': 'Registration Year', 'value': '2014',...
# 1480  Car overview  [{'key': 'Registration Year', 'value': '2018',...
# 1481  Car overview  [{'key': 'Registration Year', 'value': '2019',...
# 1482  Car overview  [{'key': 'Registration Year', 'value': '2015',...
#
#      bottomData
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# ...         ...
# ...

# %%
import pandas as pd

# Step 1: Read the Excel file
df = pd.read_excel("hyderabad_cars.xlsx")

# Step 2: Initialize an empty list to hold structured data
structured_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    row_data = {}
    
    # Convert the string representation of the dictionary to an actual dictionary
    try:
        dict_value = eval(row['new_car_feature'])  # Replace eval with ast.literal_eval for safer evaluation
        if isinstance(dict_value, dict):
            row_data = dict_value
    except Exception as e:
        print(f"Error parsing row {index}: {e}")
        row_data = None

    # Append the row dictionary to the structured data list
    structured_data.append(row_data)

# Step 4: Create a DataFrame from the list of dictionaries in 'new_car_detail'
unwound_df2 = pd.json_normalize(structured_data)

# Optional: Display the unwound DataFrame
print(unwound_df2)

# Save the unwound DataFrame to a new Excel file
#unwound_df.to_excel('unwound_new_car_detail.xlsx', index=False)
# Out:
#        heading                                                top  \
# 0     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 2     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 3     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 4     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# ...        ...                                                ...
# 1478  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1479  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1480  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1481  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1482  Features  [{'value': 'Power Steering'}, {'value': 'Power...
#
#                                                    data  \
# 0     [{'heading': 'Comfort & Convenience', 'subHead...
# 1     [{'heading': 'Comfort & Convenience', 'subHead...
# ...

# %%
import pandas as pd

# Step 1: Read the Excel file
df = pd.read_excel("hyderabad_cars.xlsx")

# Step 2: Initialize an empty list to hold structured data
structured_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    row_data = {}
    
    # Convert the string representation of the dictionary to an actual dictionary
    try:
        dict_value = eval(row['new_car_specs'])  # Replace eval with ast.literal_eval for safer evaluation
        if isinstance(dict_value, dict):
            row_data = dict_value
    except Exception as e:
        print(f"Error parsing row {index}: {e}")
        row_data = None

    # Append the row dictionary to the structured data list
    structured_data.append(row_data)

# Step 4: Create a DataFrame from the list of dictionaries in 'new_car_detail'
unwound_df3 = pd.json_normalize(structured_data)

# Optional: Display the unwound DataFrame
print(unwound_df3)

# Save the unwound DataFrame to a new Excel file
#unwound_df.to_excel('unwound_new_car_detail.xlsx', index=False)
# Out:
#              heading                                                top  \
# 0     Specifications  [{'key': 'Mileage', 'value': '16.47 kmpl'}, {'...
# 1     Specifications  [{'key': 'Mileage', 'value': '21.1 kmpl'}, {'k...
# 2     Specifications  [{'key': 'Engine', 'value': '1197 CC'}, {'key'...
# 3     Specifications  [{'key': 'Mileage', 'value': '21.4 kmpl'}, {'k...
# 4     Specifications  [{'key': 'Engine', 'value': '1997 CC'}, {'key'...
# ...              ...                                                ...
# 1478  Specifications  [{'key': 'Mileage', 'value': '15.1 kmpl'}, {'k...
# 1479  Specifications  [{'key': 'Mileage', 'value': '14.74 kmpl'}, {'...
# 1480  Specifications  [{'key': 'Mileage', 'value': '20.37 kmpl'}, {'...
# 1481  Specifications  [{'key': 'Mileage', 'value': '21.5 kmpl'}, {'k...
# 1482  Specifications  [{'key': 'Mileage', 'value': '12.99 kmpl'}, {'...
#
#                                                    data commonIcon
# ...

# %%
import pandas as pd

# Assume df1, df2, df3, and df4 are your four DataFrames

# Concatenate the DataFrames column-wise
combined_df = pd.concat([unwound_df, unwound_df1, unwound_df2, unwound_df3], axis=1)

# Optional: Display the combined DataFrame
print(combined_df)

# Save the combined DataFrame to a new Excel file if needed
combined_df.to_excel('combined_data_column_wise_hyderabad.xlsx', index=False)
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback    20,000    Automatic        1  1st Owner
# 1      0  Petrol  Hatchback    85,582       Manual        2  2nd Owner
# 2      0  Petrol        SUV    10,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback    50,750       Manual        1  1st Owner
# 4      0  Petrol        SUV    10,000    Automatic        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1478   0  Diesel        SUV    60,000       Manual        1  1st Owner
# 1479   0  Diesel      Sedan    50,000    Automatic        1  1st Owner
# 1480   0  Diesel      Sedan  1,20,000    Automatic        3  3rd Owner
# 1481   0  Diesel        SUV    50,000    Automatic        2  2nd Owner
# 1482   0  Diesel        MUV  1,00,000       Manual        1  1st Owner
#
#              oem            model  modelYear  ...  \
# 0     Volkswagen  Volkswagen Polo       2022  ...
# ...

# %%
import pandas as pd

# Example DataFrame with repeating columns (for demonstration purposes)
# combined_df = pd.DataFrame(...)  # Assume this is your existing DataFrame

# Step 1: Get the current column names
original_columns = combined_df.columns

# Step 2: Create a new list to hold unique column names
new_columns = []
column_count = {}

# Step 3: Loop through original columns and create unique names
for col in original_columns:
    if col in column_count:
        column_count[col] += 1
        new_columns.append(f"{col}_{column_count[col]}")  # Append count as suffix
    else:
        column_count[col] = 1
        new_columns.append(col)  # Keep original name for the first occurrence

# Step 4: Assign the new column names to the DataFrame
combined_df.columns = new_columns

# Optional: Display the updated DataFrame columns
print(combined_df.columns)
# Out:
# Index(['it', 'ft', 'bt', 'km', 'transmission', 'ownerNo', 'owner', 'oem',
#        'model', 'modelYear', 'centralVariantId', 'variantName', 'price',
#        'priceActual', 'priceSaving', 'priceFixedText', 'trendingText.imgUrl',
#        'trendingText.heading', 'trendingText.desc', 'heading', 'top',
#        'bottomData', 'heading_2', 'top_2', 'data', 'commonIcon', 'heading_3',
#        'top_3', 'data_2', 'commonIcon_2'],
#       dtype='object')

# %%
import pandas as pd

# Function to extract and convert 'top1' into a DataFrame
def extract_top_to_dataframe(main_df):
    rows = []  # To hold the extracted data
    
    # Loop through each row in the main DataFrame
    for _, row in main_df.iterrows():
        top3_data = row['top_3']  # Access the list directly
        
        # Check if the top1_data is a list
        if isinstance(top3_data, list):
            # Create a dictionary from the extracted key-value pairs
            row_dict = {item['key']: item['value'] for item in top3_data if 'key' in item and 'value' in item}
            rows.append(row_dict)  # Add the dictionary to the rows list
        else:
            print(f"Unexpected format for row: {row}. Expected a list but got {type(top3_data)}")
    
    # Create a new DataFrame from the rows list
    top3_df = pd.DataFrame(rows)
    return top3_df

# Extracting the DataFrame from 'top1'
top3_df = extract_top_to_dataframe(combined_df)

# Display the new DataFrame
print(top3_df)
# Out:
#          Mileage   Engine  Max Power   Torque Wheel Size Seats
# 0     16.47 kmpl   999 CC  108.62bhp    175nm        R16     5
# 1      21.1 kmpl   814 CC    55.2bhp   74.5Nm        NaN     5
# 2            NaN  1197 CC   81.80bhp  113.8Nm        NaN     5
# 3      21.4 kmpl  1197 CC    83.1bhp    115Nm         16     5
# 4            NaN  1997 CC     150bhp    320Nm         18     4
# ...          ...      ...        ...      ...        ...   ...
# 1478   15.1 kmpl  2179 CC     140bhp    330Nm         17     7
# 1479  14.74 kmpl  2993 CC   270.9bhp    600Nm         20     5
# 1480  20.37 kmpl  1995 CC  187.74bhp    400Nm        R18     5
# 1481   21.5 kmpl  1497 CC   108.5bhp    260Nm        NaN     5
# 1482  12.99 kmpl  2494 CC   100.6bhp    200Nm         15     7
#
# [1483 rows x 6 columns]

# %%
import pandas as pd

# Assuming combined_df is your existing DataFrame with a column named 'top_2'
# combined_df = ...  # Your existing DataFrame

def extract_list_of_dicts_to_dataframe(main_df, column_name):
    # Initialize a list to store the extracted data
    extracted_data = []

    for index, row in main_df.iterrows():
        # Check if the cell is a list and not empty
        if isinstance(row[column_name], list) and row[column_name]:
            # Create a dictionary from the extracted values
            row_dict = {item['value']: True for item in row[column_name]}
        else:
            row_dict = {}

        extracted_data.append(row_dict)

    # Create a DataFrame from the extracted data
    extracted_df = pd.DataFrame(extracted_data)

    return extracted_df

# Extract DataFrame for top_2
top_2_df = extract_list_of_dicts_to_dataframe(combined_df, 'top_2')

# Display the DataFrame
print("DataFrame for top_2:")
print(top_2_df)
# Out:
# DataFrame for top_2:
#      Power Steering Power Windows Front Air Conditioner Heater  \
# 0              True                True            True   True
# 1              True                True            True   True
# 2              True                True            True   True
# 3              True                True            True   True
# 4              True                True            True   True
# ...             ...                 ...             ...    ...
# 1478           True                True            True   True
# 1479           True                True            True   True
# 1480           True                True            True   True
# 1481           True                True            True   True
# 1482           True                True            True   True
#
#      Adjustable Head Lights Fog Lights Front Anti Lock Braking System  \
# 0                      True             True                     True
# ...

# %%
import pandas as pd

# Function to extract and convert 'top1' into a DataFrame
def extract_top_to_dataframe(main_df):
    rows = []  # To hold the extracted data
    
    # Loop through each row in the main DataFrame
    for _, row in main_df.iterrows():
        top_data = row['top']  # Access the list directly
        
        # Check if the top1_data is a list
        if isinstance(top_data, list):
            # Create a dictionary from the extracted key-value pairs
            row_dict = {item['key']: item['value'] for item in top_data if 'key' in item and 'value' in item}
            rows.append(row_dict)  # Add the dictionary to the rows list
        else:
            print(f"Unexpected format for row: {row}. Expected a list but got {type(top_data)}")
    
    # Create a new DataFrame from the rows list
    top_df = pd.DataFrame(rows)
    return top_df

# Extracting the DataFrame from 'top1'
top_df = extract_top_to_dataframe(combined_df)

# Display the new DataFrame
print(top_df)
# Out:
#      Registration Year     Insurance Validity Fuel Type    Seats  \
# 0                 2022  Third Party insurance    Petrol  5 Seats
# 1             Oct 2014  Third Party insurance    Petrol  5 Seats
# 2                 2023  Third Party insurance    Petrol  5 Seats
# 3             Mar 2017  Third Party insurance    Petrol  5 Seats
# 4                 2022  Third Party insurance    Petrol  4 Seats
# ...                ...                    ...       ...      ...
# 1478              2013  Third Party insurance    Diesel  7 Seats
# 1479              2014  Third Party insurance    Diesel  5 Seats
# 1480              2018  Third Party insurance    Diesel  5 Seats
# 1481              2019  Third Party insurance    Diesel  5 Seats
# 1482              2015  Third Party insurance    Diesel  7 Seats
#
#         Kms Driven   RTO     Ownership Engine Displacement Transmission  \
# 0       20,000 Kms  TS04   First Owner              999 cc    Automatic
# ...

# %%
import pandas as pd

def extract_data_to_dataframe(main_df, column_name):
    # Create a list to hold the rows for the new DataFrame
    data_rows = []
    
    # Iterate over each row in the main DataFrame
    for index, row in main_df.iterrows():
        # Check if the cell is a list and contains dictionaries
        if isinstance(row[column_name], list) and row[column_name]:
            # Extract the 'list' field from the first dictionary in the row
            list_values = row[column_name][0].get('list', [])
            # Create a dictionary to hold values for this row
            row_dict = {item['value']: True for item in list_values}
            # Append the dictionary to the rows list
            data_rows.append(row_dict)
        else:
            # If there's no data, append an empty dictionary
            data_rows.append({})

    # Create a DataFrame from the list of dictionaries
    data_df = pd.DataFrame(data_rows)

    return data_df

# Extract DataFrame for the 'data' column
data_df = extract_data_to_dataframe(combined_df, 'data')

# Display the DataFrame
print("DataFrame for data:")
print(data_df)
# Out:
# DataFrame for data:
#      Power Steering Power Windows Front Power Windows Rear  \
# 0              True                True               True
# 1              True                True                NaN
# 2              True                True               True
# 3              True                True               True
# 4              True                True                NaN
# ...             ...                 ...                ...
# 1478           True                True               True
# 1479           True                True               True
# 1480           True                True               True
# 1481           True                True               True
# 1482           True                True               True
#
#      Remote Trunk Opener Low Fuel Warning Light Accessory Power Outlet  \
# 0                   True                   True                   True
# 1                   True                   True                   True
# ...

# %%
import pandas as pd

def extract_data2_to_dataframe(main_df, column_name):
    # Create a list to hold the rows for the new DataFrame
    data_rows = []
    
    # Iterate over each row in the main DataFrame
    for index, row in main_df.iterrows():
        # Check if the cell is a list and contains dictionaries
        if isinstance(row[column_name], list) and row[column_name]:
            # Create a dictionary to hold values for this row
            row_dict = {}
            for section in row[column_name]:
                # Extract the 'list' field from each section
                for item in section.get('list', []):
                    # Use the 'key' as the column name and 'value' as the value
                    row_dict[item['key']] = item['value']
            # Append the dictionary to the rows list
            data_rows.append(row_dict)
        else:
            # If there's no data, append an empty dictionary
            data_rows.append({})

    # Create a DataFrame from the list of dictionaries
    data2_df = pd.DataFrame(data_rows)

    return data2_df

# Extract DataFrame for the 'data_2' column
data2_df = extract_data2_to_dataframe(combined_df, 'data_2')

# Display the DataFrame
print("DataFrame for data_2:")
print(data2_df)
# Out:
# DataFrame for data_2:
#        Color                               Engine Type Displacement  \
# 0     Others                           1.0L TSI Petrol          999
# 1        Red                             Petrol Engine          814
# 2     Others                          1.2 Kappa Petrol         1197
# 3        Red                         VVT Petrol Engine         1197
# 4     Others                 mStallion 150 TGDi Engine         1997
# ...      ...                                       ...          ...
# 1478  Others                       mHawk Diesel Engine         2179
# 1479    Blue                           Diesel S Engine         2993
# 1480    Blue  TwinPower Turbo Inline 4 Cylinder Engine         1995
# 1481  Others        Revotorq, 1.5L Turbocharged engine         1497
# 1482  Others                     2KD-FTV Diesel Engine         2494
#
#                    Max Power          Max Torque  No of Cylinder  \
# ...

# %%
import pandas as pd

# Assuming combined_df, top_df, top3_df, data2_df, top_2_df, data_df are already defined

# Concatenate the DataFrames column-wise
final_df_hyderabad = pd.concat([combined_df, top_df, top3_df, data2_df, top_2_df, data_df], axis=1)

# Display the final DataFrame
print("Final DataFrame (final_df_hyderabad):")
print(final_df_hyderabad)
# Out:
# Final DataFrame (final_df_hyderabad):
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback    20,000    Automatic        1  1st Owner
# 1      0  Petrol  Hatchback    85,582       Manual        2  2nd Owner
# 2      0  Petrol        SUV    10,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback    50,750       Manual        1  1st Owner
# 4      0  Petrol        SUV    10,000    Automatic        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1478   0  Diesel        SUV    60,000       Manual        1  1st Owner
# 1479   0  Diesel      Sedan    50,000    Automatic        1  1st Owner
# 1480   0  Diesel      Sedan  1,20,000    Automatic        3  3rd Owner
# 1481   0  Diesel        SUV    50,000    Automatic        2  2nd Owner
# 1482   0  Diesel        MUV  1,00,000       Manual        1  1st Owner
#
#              oem            model  modelYear  ...  Power Antenna  \
# ...

# %%
## # Assuming final_df_chennai is already defined

# Specify the file name
file_name = "final_df_hyderabad.xlsx"

# Save the DataFrame to an Excel file
final_df_hyderabad.to_excel(file_name, index=False)

print(f"DataFrame has been saved to {file_name}")
# Out:
# DataFrame has been saved to final_df_hyderabad.xlsx

# %% [markdown]
# ## Jaipur :

# %%
## import pandas as pd
import ast  # Use ast for safer evaluation of strings to dictionaries

# Step 1: Load your DataFrame from the Excel file
file_path = 'jaipur_cars.xlsx'  # Your Excel file name
df = pd.read_excel(file_path)

# Step 2: Initialize an empty list to hold the structured data
unwound_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    # Initialize a dictionary for the current row
    combined_data = {}
    
    # Specify the columns containing dictionaries
    dict_columns = ['new_car_detail', 'new_car_overview', 'new_car_feature', 'new_car_specs']
    
    # Step 4: Extract and merge dictionaries from the specified columns
    for col in dict_columns:
        try:
            # Safely convert the string representation of the dictionary to an actual dictionary
            dict_value = ast.literal_eval(row[col])  
            if isinstance(dict_value, dict):
                combined_data.update(dict_value)  # Merge the extracted dictionary
        except Exception as e:
            print(f"Error parsing row {index}, column {col}: {e}")

    # Append the combined data for the current row to the unwound data list
    unwound_data.append(combined_data)

# Step 5: Create a DataFrame from the unwound data
unwound_df = pd.DataFrame(unwound_data)

# Optional: Display the unwound DataFrame
print(unwound_df)

# Save the unwound DataFrame to a new Excel file if needed
#unwound_df.to_excel('unwound_bangalore_cars.xlsx', index=False)
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Diesel  Hatchback  1,20,000       Manual        2  2nd Owner
# 1      0  Petrol  Hatchback    66,951       Manual        1  1st Owner
# 2      0  Petrol  Hatchback    80,000    Automatic        2  2nd Owner
# 3      0  Petrol  Hatchback    44,392       Manual        1  1st Owner
# 4      0  Petrol  Hatchback    40,000    Automatic        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1115   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1116   0  Petrol  Hatchback    70,000       Manual        1  1st Owner
# 1117   0  Petrol        SUV    20,000       Manual        1  1st Owner
# 1118   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1119   0  Petrol  Hatchback    80,000       Manual        1  1st Owner
#
#             oem              model  modelYear  ...        price priceActual  \
# ...

# %%
import pandas as pd

# Step 1: Read the Excel file
df = pd.read_excel("jaipur_cars.xlsx")

# Step 2: Initialize an empty list to hold structured data
structured_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    row_data = {}
    
    # Convert the string representation of the dictionary to an actual dictionary
    try:
        dict_value = eval(row['new_car_detail'])  # Replace eval with ast.literal_eval for safer evaluation
        if isinstance(dict_value, dict):
            row_data = dict_value
    except Exception as e:
        print(f"Error parsing row {index}: {e}")
        row_data = None

    # Append the row dictionary to the structured data list
    structured_data.append(row_data)

# Step 4: Create a DataFrame from the list of dictionaries in 'new_car_detail'
unwound_df = pd.json_normalize(structured_data)

# Optional: Display the unwound DataFrame
print(unwound_df)

# Save the unwound DataFrame to a new Excel file
#unwound_df.to_excel('unwound_new_car_detail.xlsx', index=False)
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Diesel  Hatchback  1,20,000       Manual        2  2nd Owner
# 1      0  Petrol  Hatchback    66,951       Manual        1  1st Owner
# 2      0  Petrol  Hatchback    80,000    Automatic        2  2nd Owner
# 3      0  Petrol  Hatchback    44,392       Manual        1  1st Owner
# 4      0  Petrol  Hatchback    40,000    Automatic        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1115   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1116   0  Petrol  Hatchback    70,000       Manual        1  1st Owner
# 1117   0  Petrol        SUV    20,000       Manual        1  1st Owner
# 1118   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1119   0  Petrol  Hatchback    80,000       Manual        1  1st Owner
#
#             oem              model  modelYear  centralVariantId  \
# ...

# %%
import pandas as pd

# Step 1: Read the Excel file
df = pd.read_excel("jaipur_cars.xlsx")

# Step 2: Initialize an empty list to hold structured data
structured_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    row_data = {}
    
    # Convert the string representation of the dictionary to an actual dictionary
    try:
        dict_value = eval(row['new_car_overview'])  # Replace eval with ast.literal_eval for safer evaluation
        if isinstance(dict_value, dict):
            row_data = dict_value
    except Exception as e:
        print(f"Error parsing row {index}: {e}")
        row_data = None

    # Append the row dictionary to the structured data list
    structured_data.append(row_data)

# Step 4: Create a DataFrame from the list of dictionaries in 'new_car_detail'
unwound_df1 = pd.json_normalize(structured_data)

# Optional: Display the unwound DataFrame
print(unwound_df1)

# Save the unwound DataFrame to a new Excel file
#unwound_df.to_excel('unwound_new_car_detail.xlsx', index=False)
# Out:
#            heading                                                top  \
# 0     Car overview  [{'key': 'Registration Year', 'value': '2015',...
# 1     Car overview  [{'key': 'Registration Year', 'value': 'Jan 20...
# 2     Car overview  [{'key': 'Registration Year', 'value': '2016',...
# 3     Car overview  [{'key': 'Registration Year', 'value': 'Apr 20...
# 4     Car overview  [{'key': 'Registration Year', 'value': '2016',...
# ...            ...                                                ...
# 1115  Car overview  [{'key': 'Registration Year', 'value': '2011',...
# 1116  Car overview  [{'key': 'Registration Year', 'value': '2007',...
# 1117  Car overview  [{'key': 'Registration Year', 'value': '2022',...
# 1118  Car overview  [{'key': 'Registration Year', 'value': '2009',...
# 1119  Car overview  [{'key': 'Registration Year', 'value': '2018',...
#
#      bottomData
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# ...         ...
# ...

# %%
import pandas as pd

# Step 1: Read the Excel file
df = pd.read_excel("jaipur_cars.xlsx")

# Step 2: Initialize an empty list to hold structured data
structured_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    row_data = {}
    
    # Convert the string representation of the dictionary to an actual dictionary
    try:
        dict_value = eval(row['new_car_feature'])  # Replace eval with ast.literal_eval for safer evaluation
        if isinstance(dict_value, dict):
            row_data = dict_value
    except Exception as e:
        print(f"Error parsing row {index}: {e}")
        row_data = None

    # Append the row dictionary to the structured data list
    structured_data.append(row_data)

# Step 4: Create a DataFrame from the list of dictionaries in 'new_car_detail'
unwound_df2 = pd.json_normalize(structured_data)

# Optional: Display the unwound DataFrame
print(unwound_df2)

# Save the unwound DataFrame to a new Excel file
#unwound_df.to_excel('unwound_new_car_detail.xlsx', index=False)
# Out:
#        heading                                                top  \
# 0     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 2     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 3     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 4     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# ...        ...                                                ...
# 1115  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1116  Features  [{'value': 'Low Fuel Warning Light'}, {'value'...
# 1117  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1118  Features  [{'value': 'Low Fuel Warning Light'}, {'value'...
# 1119  Features  [{'value': 'Power Steering'}, {'value': 'Power...
#
#                                                    data  \
# 0     [{'heading': 'Comfort & Convenience', 'subHead...
# 1     [{'heading': 'Comfort & Convenience', 'subHead...
# ...

# %%
import pandas as pd

# Step 1: Read the Excel file
df = pd.read_excel("jaipur_cars.xlsx")

# Step 2: Initialize an empty list to hold structured data
structured_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    row_data = {}
    
    # Convert the string representation of the dictionary to an actual dictionary
    try:
        dict_value = eval(row['new_car_specs'])  # Replace eval with ast.literal_eval for safer evaluation
        if isinstance(dict_value, dict):
            row_data = dict_value
    except Exception as e:
        print(f"Error parsing row {index}: {e}")
        row_data = None

    # Append the row dictionary to the structured data list
    structured_data.append(row_data)

# Step 4: Create a DataFrame from the list of dictionaries in 'new_car_detail'
unwound_df3 = pd.json_normalize(structured_data)

# Optional: Display the unwound DataFrame
print(unwound_df3)

# Save the unwound DataFrame to a new Excel file
#unwound_df.to_excel('unwound_new_car_detail.xlsx', index=False)
# Out:
#              heading                                                top  \
# 0     Specifications  [{'key': 'Mileage', 'value': '22.54 kmpl'}, {'...
# 1     Specifications  [{'key': 'Mileage', 'value': '22.38 kmpl'}, {'...
# 2     Specifications  [{'key': 'Mileage', 'value': '23.1 kmpl'}, {'k...
# 3     Specifications  [{'key': 'Mileage', 'value': '18.9 kmpl'}, {'k...
# 4     Specifications  [{'key': 'Mileage', 'value': '20.51 kmpl'}, {'...
# ...              ...                                                ...
# 1115  Specifications  [{'key': 'Mileage', 'value': '18.6 kmpl'}, {'k...
# 1116  Specifications  [{'key': 'Mileage', 'value': '19.7 kmpl'}, {'k...
# 1117  Specifications  [{'key': 'Mileage', 'value': '19.17 kmpl'}, {'...
# 1118  Specifications  [{'key': 'Mileage', 'value': '19.7 kmpl'}, {'k...
# 1119  Specifications  [{'key': 'Mileage', 'value': '21.4 kmpl'}, {'k...
#
#                                                    data commonIcon
# ...

# %%
import pandas as pd

# Assume df1, df2, df3, and df4 are your four DataFrames

# Concatenate the DataFrames column-wise
combined_df = pd.concat([unwound_df, unwound_df1, unwound_df2, unwound_df3], axis=1)

# Optional: Display the combined DataFrame
print(combined_df)

# Save the combined DataFrame to a new Excel file if needed
combined_df.to_excel('combined_data_column_wise_jaipur.xlsx', index=False)
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Diesel  Hatchback  1,20,000       Manual        2  2nd Owner
# 1      0  Petrol  Hatchback    66,951       Manual        1  1st Owner
# 2      0  Petrol  Hatchback    80,000    Automatic        2  2nd Owner
# 3      0  Petrol  Hatchback    44,392       Manual        1  1st Owner
# 4      0  Petrol  Hatchback    40,000    Automatic        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1115   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1116   0  Petrol  Hatchback    70,000       Manual        1  1st Owner
# 1117   0  Petrol        SUV    20,000       Manual        1  1st Owner
# 1118   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1119   0  Petrol  Hatchback    80,000       Manual        1  1st Owner
#
#             oem              model  modelYear  ...  \
# 0       Hyundai        Hyundai i20       2015  ...
# ...

# %%
import pandas as pd

# Example DataFrame with repeating columns (for demonstration purposes)
# combined_df = pd.DataFrame(...)  # Assume this is your existing DataFrame

# Step 1: Get the current column names
original_columns = combined_df.columns

# Step 2: Create a new list to hold unique column names
new_columns = []
column_count = {}

# Step 3: Loop through original columns and create unique names
for col in original_columns:
    if col in column_count:
        column_count[col] += 1
        new_columns.append(f"{col}_{column_count[col]}")  # Append count as suffix
    else:
        column_count[col] = 1
        new_columns.append(col)  # Keep original name for the first occurrence

# Step 4: Assign the new column names to the DataFrame
combined_df.columns = new_columns

# Optional: Display the updated DataFrame columns
print(combined_df.columns)
# Out:
# Index(['it', 'ft', 'bt', 'km', 'transmission', 'ownerNo', 'owner', 'oem',
#        'model', 'modelYear', 'centralVariantId', 'variantName', 'price',
#        'priceActual', 'priceSaving', 'priceFixedText', 'trendingText.imgUrl',
#        'trendingText.heading', 'trendingText.desc', 'heading', 'top',
#        'bottomData', 'heading_2', 'top_2', 'data', 'commonIcon', 'heading_3',
#        'top_3', 'data_2', 'commonIcon_2'],
#       dtype='object')

# %%
import pandas as pd

# Function to extract and convert 'top1' into a DataFrame
def extract_top_to_dataframe(main_df):
    rows = []  # To hold the extracted data
    
    # Loop through each row in the main DataFrame
    for _, row in main_df.iterrows():
        top3_data = row['top_3']  # Access the list directly
        
        # Check if the top1_data is a list
        if isinstance(top3_data, list):
            # Create a dictionary from the extracted key-value pairs
            row_dict = {item['key']: item['value'] for item in top3_data if 'key' in item and 'value' in item}
            rows.append(row_dict)  # Add the dictionary to the rows list
        else:
            print(f"Unexpected format for row: {row}. Expected a list but got {type(top3_data)}")
    
    # Create a new DataFrame from the rows list
    top3_df = pd.DataFrame(rows)
    return top3_df

# Extracting the DataFrame from 'top1'
top3_df = extract_top_to_dataframe(combined_df)

# Display the new DataFrame
print(top3_df)
# Out:
#          Mileage   Engine Max Power    Torque Wheel Size Seats
# 0     22.54 kmpl  1396 CC  88.73bhp   219.7Nm         16     5
# 1     22.38 kmpl  1197 CC  88.50bhp     113Nm        NaN     5
# 2      23.1 kmpl   998 CC  67.04bhp      90Nm        NaN     5
# 3      18.9 kmpl  1197 CC  81.86bhp  113.75nm        NaN     5
# 4     20.51 kmpl   998 CC     67bhp      90Nm        NaN     5
# ...          ...      ...       ...       ...        ...   ...
# 1115   18.6 kmpl  1199 CC   79.4bhp     108Nm         14     5
# 1116   19.7 kmpl   796 CC   46.3bhp      62Nm         12     5
# 1117  19.17 kmpl   999 CC  71.01bhp      96Nm         16     5
# 1118   19.7 kmpl   796 CC   46.3bhp      62Nm         12     5
# 1119   21.4 kmpl  1197 CC   83.1bhp     115Nm        NaN     5
#
# [1120 rows x 6 columns]

# %%
import pandas as pd

# Assuming combined_df is your existing DataFrame with a column named 'top_2'
# combined_df = ...  # Your existing DataFrame

def extract_list_of_dicts_to_dataframe(main_df, column_name):
    # Initialize a list to store the extracted data
    extracted_data = []

    for index, row in main_df.iterrows():
        # Check if the cell is a list and not empty
        if isinstance(row[column_name], list) and row[column_name]:
            # Create a dictionary from the extracted values
            row_dict = {item['value']: True for item in row[column_name]}
        else:
            row_dict = {}

        extracted_data.append(row_dict)

    # Create a DataFrame from the extracted data
    extracted_df = pd.DataFrame(extracted_data)

    return extracted_df

# Extract DataFrame for top_2
top_2_df = extract_list_of_dicts_to_dataframe(combined_df, 'top_2')

# Display the DataFrame
print("DataFrame for top_2:")
print(top_2_df)
# Out:
# DataFrame for top_2:
#      Power Steering Power Windows Front Air Conditioner Heater  \
# 0              True                True            True   True
# 1              True                True            True   True
# 2              True                True            True   True
# 3              True                True            True   True
# 4              True                True            True   True
# ...             ...                 ...             ...    ...
# 1115           True                True            True   True
# 1116            NaN                 NaN             NaN    NaN
# 1117           True                True            True   True
# 1118            NaN                 NaN             NaN    NaN
# 1119           True                True            True   True
#
#      Adjustable Head Lights Fog Lights Front Anti Lock Braking System  \
# 0                      True             True                     True
# ...

# %%
import pandas as pd

# Function to extract and convert 'top1' into a DataFrame
def extract_top_to_dataframe(main_df):
    rows = []  # To hold the extracted data
    
    # Loop through each row in the main DataFrame
    for _, row in main_df.iterrows():
        top_data = row['top']  # Access the list directly
        
        # Check if the top1_data is a list
        if isinstance(top_data, list):
            # Create a dictionary from the extracted key-value pairs
            row_dict = {item['key']: item['value'] for item in top_data if 'key' in item and 'value' in item}
            rows.append(row_dict)  # Add the dictionary to the rows list
        else:
            print(f"Unexpected format for row: {row}. Expected a list but got {type(top_data)}")
    
    # Create a new DataFrame from the rows list
    top_df = pd.DataFrame(rows)
    return top_df

# Extracting the DataFrame from 'top1'
top_df = extract_top_to_dataframe(combined_df)

# Display the new DataFrame
print(top_df)
# Out:
#      Registration Year     Insurance Validity Fuel Type    Seats  \
# 0                 2015  Third Party insurance    Diesel  5 Seats
# 1             Jan 2012            Third Party    Petrol  5 Seats
# 2                 2016  Third Party insurance    Petrol  5 Seats
# 3             Apr 2017  Third Party insurance    Petrol  5 Seats
# 4                 2016  Third Party insurance    Petrol  5 Seats
# ...                ...                    ...       ...      ...
# 1115              2011  Third Party insurance    Petrol  5 Seats
# 1116              2007  Third Party insurance    Petrol  5 Seats
# 1117              2022  Third Party insurance    Petrol  5 Seats
# 1118              2009  Third Party insurance    Petrol  5 Seats
# 1119              2018  Third Party insurance    Petrol  5 Seats
#
#         Kms Driven   RTO     Ownership Engine Displacement Transmission  \
# 0     1,20,000 Kms  RJ13  Second Owner             1396 cc       Manual
# ...

# %%
import pandas as pd

def extract_data_to_dataframe(main_df, column_name):
    # Create a list to hold the rows for the new DataFrame
    data_rows = []
    
    # Iterate over each row in the main DataFrame
    for index, row in main_df.iterrows():
        # Check if the cell is a list and contains dictionaries
        if isinstance(row[column_name], list) and row[column_name]:
            # Extract the 'list' field from the first dictionary in the row
            list_values = row[column_name][0].get('list', [])
            # Create a dictionary to hold values for this row
            row_dict = {item['value']: True for item in list_values}
            # Append the dictionary to the rows list
            data_rows.append(row_dict)
        else:
            # If there's no data, append an empty dictionary
            data_rows.append({})

    # Create a DataFrame from the list of dictionaries
    data_df = pd.DataFrame(data_rows)

    return data_df

# Extract DataFrame for the 'data' column
data_df = extract_data_to_dataframe(combined_df, 'data')

# Display the DataFrame
print("DataFrame for data:")
print(data_df)
# Out:
# DataFrame for data:
#      Power Steering Power Windows Front Power Windows Rear  \
# 0              True                True               True
# 1              True                True               True
# 2              True                True               True
# 3              True                True               True
# 4              True                True               True
# ...             ...                 ...                ...
# 1115           True                True               True
# 1116            NaN                 NaN                NaN
# 1117           True                True               True
# 1118            NaN                 NaN                NaN
# 1119           True                True               True
#
#      Air Quality Control Remote Trunk Opener Remote Fuel Lid Opener  \
# 0                   True                True                   True
# 1                    NaN                 NaN                    NaN
# ...

# %%
import pandas as pd

def extract_data2_to_dataframe(main_df, column_name):
    # Create a list to hold the rows for the new DataFrame
    data_rows = []
    
    # Iterate over each row in the main DataFrame
    for index, row in main_df.iterrows():
        # Check if the cell is a list and contains dictionaries
        if isinstance(row[column_name], list) and row[column_name]:
            # Create a dictionary to hold values for this row
            row_dict = {}
            for section in row[column_name]:
                # Extract the 'list' field from each section
                for item in section.get('list', []):
                    # Use the 'key' as the column name and 'value' as the value
                    row_dict[item['key']] = item['value']
            # Append the dictionary to the rows list
            data_rows.append(row_dict)
        else:
            # If there's no data, append an empty dictionary
            data_rows.append({})

    # Create a DataFrame from the list of dictionaries
    data2_df = pd.DataFrame(data_rows)

    return data2_df

# Extract DataFrame for the 'data_2' column
data2_df = extract_data2_to_dataframe(combined_df, 'data_2')

# Display the DataFrame
print("DataFrame for data_2:")
print(data2_df)
# Out:
# DataFrame for data_2:
#        Color               Engine Type Displacement         Max Power  \
# 0     Others     U2 CRDI Diesel Engine         1396  88.73bhp@4000rpm
# 1      White         K Series Dual jet         1197  88.50bhp@6000rpm
# 2     Others               K10B Engine          998  67.04bhp@6000rpm
# 3     Silver  Kappa VTVT Petrol Engine         1197  81.86bhp@6000rpm
# 4     Silver        K10B Petrol Engine          998     67bhp@6000rpm
# ...      ...                       ...          ...               ...
# 1115  Others           Smartech Engine         1199   79.4bhp@6200rpm
# 1116  Others            In-Line Engine          796   46.3bhp@6200rpm
# 1117  Others               1.0L energy          999  71.01bhp@6250rpm
# 1118  Others            In-Line Engine          796   46.3bhp@6200rpm
# 1119  Others         VVT Petrol Engine         1197   83.1bhp@6000rpm
#
#                 Max Torque  No of Cylinder  Values per Cylinder  \
# ...

# %%
import pandas as pd

# Assuming combined_df, top_df, top3_df, data2_df, top_2_df, data_df are already defined

# Concatenate the DataFrames column-wise
final_df_jaipur = pd.concat([combined_df, top_df, top3_df, data2_df, top_2_df, data_df], axis=1)

# Display the final DataFrame
print("Final DataFrame (final_df_jaipur):")
print(final_df_jaipur)
# Out:
# Final DataFrame (final_df_jaipur):
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Diesel  Hatchback  1,20,000       Manual        2  2nd Owner
# 1      0  Petrol  Hatchback    66,951       Manual        1  1st Owner
# 2      0  Petrol  Hatchback    80,000    Automatic        2  2nd Owner
# 3      0  Petrol  Hatchback    44,392       Manual        1  1st Owner
# 4      0  Petrol  Hatchback    40,000    Automatic        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1115   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1116   0  Petrol  Hatchback    70,000       Manual        1  1st Owner
# 1117   0  Petrol        SUV    20,000       Manual        1  1st Owner
# 1118   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1119   0  Petrol  Hatchback    80,000       Manual        1  1st Owner
#
#             oem              model  modelYear  ...  Remote Climate Control  \
# ...

# %%
## # Assuming final_df_chennai is already defined

# Specify the file name
file_name = "final_df_jaipur.xlsx"

# Save the DataFrame to an Excel file
final_df_jaipur.to_excel(file_name, index=False)

print(f"DataFrame has been saved to {file_name}")
# Out:
# DataFrame has been saved to final_df_jaipur.xlsx

# %% [markdown]
# ## Kolkata :

# %%
## import pandas as pd
import ast  # Use ast for safer evaluation of strings to dictionaries

# Step 1: Load your DataFrame from the Excel file
file_path = 'kolkata_cars.xlsx'  # Your Excel file name
df = pd.read_excel(file_path)

# Step 2: Initialize an empty list to hold the structured data
unwound_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    # Initialize a dictionary for the current row
    combined_data = {}
    
    # Specify the columns containing dictionaries
    dict_columns = ['new_car_detail', 'new_car_overview', 'new_car_feature', 'new_car_specs']
    
    # Step 4: Extract and merge dictionaries from the specified columns
    for col in dict_columns:
        try:
            # Safely convert the string representation of the dictionary to an actual dictionary
            dict_value = ast.literal_eval(row[col])  
            if isinstance(dict_value, dict):
                combined_data.update(dict_value)  # Merge the extracted dictionary
        except Exception as e:
            print(f"Error parsing row {index}, column {col}: {e}")

    # Append the combined data for the current row to the unwound data list
    unwound_data.append(combined_data)

# Step 5: Create a DataFrame from the unwound data
unwound_df = pd.DataFrame(unwound_data)

# Optional: Display the unwound DataFrame
print(unwound_df)

# Save the unwound DataFrame to a new Excel file if needed
#unwound_df.to_excel('unwound_bangalore_cars.xlsx', index=False)
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol      Sedan    70,000    Automatic        3  3rd Owner
# 1      0  Petrol  Hatchback    23,981       Manual        1  1st Owner
# 2      0  Petrol        SUV     7,100    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback    71,574       Manual        2  2nd Owner
# 4      0  Diesel        SUV    50,000    Automatic        2  2nd Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1376   0  Petrol  Hatchback    10,000       Manual        1  1st Owner
# 1377   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1378   0  Petrol      Sedan    50,000    Automatic        3  3rd Owner
# 1379   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1380   0  Diesel        SUV  1,20,000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  ...        price  \
# ...

# %%
import pandas as pd

# Step 1: Read the Excel file
df = pd.read_excel("kolkata_cars.xlsx")

# Step 2: Initialize an empty list to hold structured data
structured_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    row_data = {}
    
    # Convert the string representation of the dictionary to an actual dictionary
    try:
        dict_value = eval(row['new_car_detail'])  # Replace eval with ast.literal_eval for safer evaluation
        if isinstance(dict_value, dict):
            row_data = dict_value
    except Exception as e:
        print(f"Error parsing row {index}: {e}")
        row_data = None

    # Append the row dictionary to the structured data list
    structured_data.append(row_data)

# Step 4: Create a DataFrame from the list of dictionaries in 'new_car_detail'
unwound_df = pd.json_normalize(structured_data)

# Optional: Display the unwound DataFrame
print(unwound_df)

# Save the unwound DataFrame to a new Excel file
#unwound_df.to_excel('unwound_new_car_detail.xlsx', index=False)
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol      Sedan    70,000    Automatic        3  3rd Owner
# 1      0  Petrol  Hatchback    23,981       Manual        1  1st Owner
# 2      0  Petrol        SUV     7,100    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback    71,574       Manual        2  2nd Owner
# 4      0  Diesel        SUV    50,000    Automatic        2  2nd Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1376   0  Petrol  Hatchback    10,000       Manual        1  1st Owner
# 1377   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1378   0  Petrol      Sedan    50,000    Automatic        3  3rd Owner
# 1379   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1380   0  Diesel        SUV  1,20,000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  centralVariantId  \
# ...

# %%
import pandas as pd

# Step 1: Read the Excel file
df = pd.read_excel("kolkata_cars.xlsx")

# Step 2: Initialize an empty list to hold structured data
structured_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    row_data = {}
    
    # Convert the string representation of the dictionary to an actual dictionary
    try:
        dict_value = eval(row['new_car_overview'])  # Replace eval with ast.literal_eval for safer evaluation
        if isinstance(dict_value, dict):
            row_data = dict_value
    except Exception as e:
        print(f"Error parsing row {index}: {e}")
        row_data = None

    # Append the row dictionary to the structured data list
    structured_data.append(row_data)

# Step 4: Create a DataFrame from the list of dictionaries in 'new_car_detail'
unwound_df1 = pd.json_normalize(structured_data)

# Optional: Display the unwound DataFrame
print(unwound_df1)

# Save the unwound DataFrame to a new Excel file
#unwound_df.to_excel('unwound_new_car_detail.xlsx', index=False)
# Out:
#            heading                                                top  \
# 0     Car overview  [{'key': 'Registration Year', 'value': '2014',...
# 1     Car overview  [{'key': 'Registration Year', 'value': 'Jul 20...
# 2     Car overview  [{'key': 'Registration Year', 'value': 'Nov 20...
# 3     Car overview  [{'key': 'Registration Year', 'value': 'Feb 20...
# 4     Car overview  [{'key': 'Registration Year', 'value': '2014',...
# ...            ...                                                ...
# 1376  Car overview  [{'key': 'Registration Year', 'value': '2022',...
# 1377  Car overview  [{'key': 'Registration Year', 'value': '2014',...
# 1378  Car overview  [{'key': 'Registration Year', 'value': '2011',...
# 1379  Car overview  [{'key': 'Registration Year', 'value': '2012',...
# 1380  Car overview  [{'key': 'Registration Year', 'value': '2017',...
#
#      bottomData
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# ...         ...
# ...

# %%
import pandas as pd

# Step 1: Read the Excel file
df = pd.read_excel("kolkata_cars.xlsx")

# Step 2: Initialize an empty list to hold structured data
structured_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    row_data = {}
    
    # Convert the string representation of the dictionary to an actual dictionary
    try:
        dict_value = eval(row['new_car_feature'])  # Replace eval with ast.literal_eval for safer evaluation
        if isinstance(dict_value, dict):
            row_data = dict_value
    except Exception as e:
        print(f"Error parsing row {index}: {e}")
        row_data = None

    # Append the row dictionary to the structured data list
    structured_data.append(row_data)

# Step 4: Create a DataFrame from the list of dictionaries in 'new_car_detail'
unwound_df2 = pd.json_normalize(structured_data)

# Optional: Display the unwound DataFrame
print(unwound_df2)

# Save the unwound DataFrame to a new Excel file
#unwound_df.to_excel('unwound_new_car_detail.xlsx', index=False)
# Out:
#        heading                                                top  \
# 0     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 2     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 3     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 4     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# ...        ...                                                ...
# 1376  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1377  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1378  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1379  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1380  Features  [{'value': 'Power Steering'}, {'value': 'Power...
#
#                                                    data  \
# 0     [{'heading': 'Comfort & Convenience', 'subHead...
# 1     [{'heading': 'Comfort & Convenience', 'subHead...
# ...

# %%
import pandas as pd

# Step 1: Read the Excel file
df = pd.read_excel("kolkata_cars.xlsx")

# Step 2: Initialize an empty list to hold structured data
structured_data = []

# Step 3: Loop through each row of the DataFrame
for index, row in df.iterrows():
    row_data = {}
    
    # Convert the string representation of the dictionary to an actual dictionary
    try:
        dict_value = eval(row['new_car_specs'])  # Replace eval with ast.literal_eval for safer evaluation
        if isinstance(dict_value, dict):
            row_data = dict_value
    except Exception as e:
        print(f"Error parsing row {index}: {e}")
        row_data = None

    # Append the row dictionary to the structured data list
    structured_data.append(row_data)

# Step 4: Create a DataFrame from the list of dictionaries in 'new_car_detail'
unwound_df3 = pd.json_normalize(structured_data)

# Optional: Display the unwound DataFrame
print(unwound_df3)

# Save the unwound DataFrame to a new Excel file
#unwound_df.to_excel('unwound_new_car_detail.xlsx', index=False)
# Out:
#              heading                                                top  \
# 0     Specifications  [{'key': 'Mileage', 'value': '19.16 kmpl'}, {'...
# 1     Specifications  [{'key': 'Mileage', 'value': '22.7 kmpl'}, {'k...
# 2     Specifications  [{'key': 'Mileage', 'value': '19.03 kmpl'}, {'...
# 3     Specifications  [{'key': 'Mileage', 'value': '17 kmpl'}, {'key...
# 4     Specifications  [{'key': 'Mileage', 'value': '15.73 kmpl'}, {'...
# ...              ...                                                ...
# 1376  Specifications  [{'key': 'Mileage', 'value': '25.24 kmpl'}, {'...
# 1377  Specifications  [{'key': 'Mileage', 'value': '22.74 kmpl'}, {'...
# 1378  Specifications  [{'key': 'Mileage', 'value': '11.74 kmpl'}, {'...
# 1379  Specifications  [{'key': 'Mileage', 'value': '18.5 kmpl'}, {'k...
# 1380  Specifications  [{'key': 'Mileage', 'value': '19.72 kmpl'}, {'...
#
#                                                    data commonIcon
# ...

# %%
import pandas as pd

# Assume df1, df2, df3, and df4 are your four DataFrames

# Concatenate the DataFrames column-wise
combined_df = pd.concat([unwound_df, unwound_df1, unwound_df2, unwound_df3], axis=1)

# Optional: Display the combined DataFrame
print(combined_df)

# Save the combined DataFrame to a new Excel file if needed
combined_df.to_excel('combined_data_column_wise_kolkata.xlsx', index=False)
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol      Sedan    70,000    Automatic        3  3rd Owner
# 1      0  Petrol  Hatchback    23,981       Manual        1  1st Owner
# 2      0  Petrol        SUV     7,100    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback    71,574       Manual        2  2nd Owner
# 4      0  Diesel        SUV    50,000    Automatic        2  2nd Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1376   0  Petrol  Hatchback    10,000       Manual        1  1st Owner
# 1377   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1378   0  Petrol      Sedan    50,000    Automatic        3  3rd Owner
# 1379   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1380   0  Diesel        SUV  1,20,000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  ...  \
# ...

# %%
import pandas as pd

# Example DataFrame with repeating columns (for demonstration purposes)
# combined_df = pd.DataFrame(...)  # Assume this is your existing DataFrame

# Step 1: Get the current column names
original_columns = combined_df.columns

# Step 2: Create a new list to hold unique column names
new_columns = []
column_count = {}

# Step 3: Loop through original columns and create unique names
for col in original_columns:
    if col in column_count:
        column_count[col] += 1
        new_columns.append(f"{col}_{column_count[col]}")  # Append count as suffix
    else:
        column_count[col] = 1
        new_columns.append(col)  # Keep original name for the first occurrence

# Step 4: Assign the new column names to the DataFrame
combined_df.columns = new_columns

# Optional: Display the updated DataFrame columns
print(combined_df.columns)
# Out:
# Index(['it', 'ft', 'bt', 'km', 'transmission', 'ownerNo', 'owner', 'oem',
#        'model', 'modelYear', 'centralVariantId', 'variantName', 'price',
#        'priceActual', 'priceSaving', 'priceFixedText', 'trendingText.imgUrl',
#        'trendingText.heading', 'trendingText.desc', 'heading', 'top',
#        'bottomData', 'heading_2', 'top_2', 'data', 'commonIcon', 'heading_3',
#        'top_3', 'data_2', 'commonIcon_2'],
#       dtype='object')

# %%
import pandas as pd

# Function to extract and convert 'top1' into a DataFrame
def extract_top_to_dataframe(main_df):
    rows = []  # To hold the extracted data
    
    # Loop through each row in the main DataFrame
    for _, row in main_df.iterrows():
        top3_data = row['top_3']  # Access the list directly
        
        # Check if the top1_data is a list
        if isinstance(top3_data, list):
            # Create a dictionary from the extracted key-value pairs
            row_dict = {item['key']: item['value'] for item in top3_data if 'key' in item and 'value' in item}
            rows.append(row_dict)  # Add the dictionary to the rows list
        else:
            print(f"Unexpected format for row: {row}. Expected a list but got {type(top3_data)}")
    
    # Create a new DataFrame from the rows list
    top3_df = pd.DataFrame(rows)
    return top3_df

# Extracting the DataFrame from 'top1'
top3_df = extract_top_to_dataframe(combined_df)

# Display the new DataFrame
print(top3_df)
# Out:
#          Mileage   Engine          Max Power                 Torque  \
# 0     19.16 kmpl  2494 CC           158.2bhp                  213Nm
# 1      22.7 kmpl   799 CC           53.64bhp                   72Nm
# 2     19.03 kmpl   999 CC           71.01bhp                   96Nm
# 3        17 kmpl  1197 CC  80 PS at 5200 rpm  11.4 kgm at 4,000 rpm
# 4     15.73 kmpl  1968 CC          174.33bhp                  380Nm
# ...          ...      ...                ...                    ...
# 1376  25.24 kmpl   998 CC           65.71bhp                   89Nm
# 1377  22.74 kmpl   796 CC            47.3bhp                   69Nm
# 1378  11.74 kmpl  1796 CC             186bhp                  285Nm
# 1379   18.5 kmpl  1197 CC           85.80bhp                  114Nm
# 1380  19.72 kmpl  1461 CC          108.45bhp                  245Nm
#
#      Wheel Size Seats
# 0            17     5
# 1           NaN     5
# 2           NaN     5
# 3            14     5
# 4            16     5
# ...

# %%
import pandas as pd

# Assuming combined_df is your existing DataFrame with a column named 'top_2'
# combined_df = ...  # Your existing DataFrame

def extract_list_of_dicts_to_dataframe(main_df, column_name):
    # Initialize a list to store the extracted data
    extracted_data = []

    for index, row in main_df.iterrows():
        # Check if the cell is a list and not empty
        if isinstance(row[column_name], list) and row[column_name]:
            # Create a dictionary from the extracted values
            row_dict = {item['value']: True for item in row[column_name]}
        else:
            row_dict = {}

        extracted_data.append(row_dict)

    # Create a DataFrame from the extracted data
    extracted_df = pd.DataFrame(extracted_data)

    return extracted_df

# Extract DataFrame for top_2
top_2_df = extract_list_of_dicts_to_dataframe(combined_df, 'top_2')

# Display the DataFrame
print("DataFrame for top_2:")
print(top_2_df)
# Out:
# DataFrame for top_2:
#      Power Steering Power Windows Front Air Conditioner Heater  \
# 0              True                True            True   True
# 1              True                True            True   True
# 2              True                True            True   True
# 3              True                True            True   True
# 4              True                True            True   True
# ...             ...                 ...             ...    ...
# 1376           True                True            True   True
# 1377           True                True            True   True
# 1378           True                True            True   True
# 1379           True                True            True   True
# 1380           True                True            True   True
#
#      Adjustable Head Lights Fog Lights Front Anti Lock Braking System  \
# 0                      True             True                     True
# ...

# %%
import pandas as pd

# Function to extract and convert 'top1' into a DataFrame
def extract_top_to_dataframe(main_df):
    rows = []  # To hold the extracted data
    
    # Loop through each row in the main DataFrame
    for _, row in main_df.iterrows():
        top_data = row['top']  # Access the list directly
        
        # Check if the top1_data is a list
        if isinstance(top_data, list):
            # Create a dictionary from the extracted key-value pairs
            row_dict = {item['key']: item['value'] for item in top_data if 'key' in item and 'value' in item}
            rows.append(row_dict)  # Add the dictionary to the rows list
        else:
            print(f"Unexpected format for row: {row}. Expected a list but got {type(top_data)}")
    
    # Create a new DataFrame from the rows list
    top_df = pd.DataFrame(rows)
    return top_df

# Extracting the DataFrame from 'top1'
top_df = extract_top_to_dataframe(combined_df)

# Display the new DataFrame
print(top_df)
# Out:
#      Registration Year     Insurance Validity Fuel Type    Seats  \
# 0                 2014  Third Party insurance    Petrol  5 Seats
# 1             Jul 2017          Comprehensive    Petrol  5 Seats
# 2             Nov 2021          Comprehensive    Petrol  5 Seats
# 3             Feb 2012            Third Party    Petrol  5 Seats
# 4                 2014  Third Party insurance    Diesel  5 Seats
# ...                ...                    ...       ...      ...
# 1376              2022  Third Party insurance    Petrol  5 Seats
# 1377              2014  Third Party insurance    Petrol  5 Seats
# 1378              2011  Third Party insurance    Petrol  5 Seats
# 1379              2012  Third Party insurance    Petrol  5 Seats
# 1380              2017  Third Party insurance    Diesel  5 Seats
#
#         Kms Driven   RTO     Ownership Engine Displacement Transmission  \
# 0       70,000 Kms  WB02   Third Owner             2494 cc    Automatic
# ...

# %%
import pandas as pd

def extract_data_to_dataframe(main_df, column_name):
    # Create a list to hold the rows for the new DataFrame
    data_rows = []
    
    # Iterate over each row in the main DataFrame
    for index, row in main_df.iterrows():
        # Check if the cell is a list and contains dictionaries
        if isinstance(row[column_name], list) and row[column_name]:
            # Extract the 'list' field from the first dictionary in the row
            list_values = row[column_name][0].get('list', [])
            # Create a dictionary to hold values for this row
            row_dict = {item['value']: True for item in list_values}
            # Append the dictionary to the rows list
            data_rows.append(row_dict)
        else:
            # If there's no data, append an empty dictionary
            data_rows.append({})

    # Create a DataFrame from the list of dictionaries
    data_df = pd.DataFrame(data_rows)

    return data_df

# Extract DataFrame for the 'data' column
data_df = extract_data_to_dataframe(combined_df, 'data')

# Display the DataFrame
print("DataFrame for data:")
print(data_df)
# Out:
# DataFrame for data:
#      Power Steering Power Windows Front Power Windows Rear  \
# 0              True                True               True
# 1              True                True                NaN
# 2              True                True               True
# 3              True                True               True
# 4              True                True               True
# ...             ...                 ...                ...
# 1376           True                True               True
# 1377           True                True                NaN
# 1378           True                True               True
# 1379           True                True               True
# 1380           True                True               True
#
#      Air Quality Control Remote Trunk Opener Low Fuel Warning Light  \
# 0                   True                True                   True
# 1                    NaN                True                   True
# ...

# %%
import pandas as pd

def extract_data2_to_dataframe(main_df, column_name):
    # Create a list to hold the rows for the new DataFrame
    data_rows = []
    
    # Iterate over each row in the main DataFrame
    for index, row in main_df.iterrows():
        # Check if the cell is a list and contains dictionaries
        if isinstance(row[column_name], list) and row[column_name]:
            # Create a dictionary to hold values for this row
            row_dict = {}
            for section in row[column_name]:
                # Extract the 'list' field from each section
                for item in section.get('list', []):
                    # Use the 'key' as the column name and 'value' as the value
                    row_dict[item['key']] = item['value']
            # Append the dictionary to the rows list
            data_rows.append(row_dict)
        else:
            # If there's no data, append an empty dictionary
            data_rows.append({})

    # Create a DataFrame from the list of dictionaries
    data2_df = pd.DataFrame(data_rows)

    return data2_df

# Extract DataFrame for the 'data_2' column
data2_df = extract_data2_to_dataframe(combined_df, 'data_2')

# Display the DataFrame
print("DataFrame for data_2:")
print(data2_df)
# Out:
# DataFrame for data_2:
#        Color             Engine Type Displacement          Max Power  \
# 0      White  2AR FXE Petrol Engine          2494   158.2bhp@5700rpm
# 1        Red      0.8L Petrol Engine          799   53.64bhp@5678rpm
# 2       Blue             1.0L energy          999   71.01bhp@6250rpm
# 3        Red          In-Line Engine         1197  80 PS at 5200 rpm
# 4      White       TDI Diesel Engine         1968  174.33bhp@4200rpm
# ...      ...                     ...          ...                ...
# 1376  Others                    K10C          998   65.71bhp@5500rpm
# 1377  Others       F8D Petrol Engine          796    47.3bhp@6000rpm
# 1378  Others  Blue Efficiency Engine         1796     186bhp@5600rpm
# 1379  Others  K Series Petrol Engine         1197   85.80bhp@6000rpm
# 1380  Others   dCi THP Diesel Engine         1461  108.45bhp@4000rpm
#
#                  Max Torque  No of Cylinder  Values per Cylinder  \
# ...

# %%
import pandas as pd

# Assuming combined_df, top_df, top3_df, data2_df, top_2_df, data_df are already defined

# Concatenate the DataFrames column-wise
final_df_kolkata = pd.concat([combined_df, top_df, top3_df, data2_df, top_2_df, data_df], axis=1)

# Display the final DataFrame
print("Final DataFrame (final_df_kolkata):")
print(final_df_kolkata)
# Out:
# Final DataFrame (final_df_kolkata):
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol      Sedan    70,000    Automatic        3  3rd Owner
# 1      0  Petrol  Hatchback    23,981       Manual        1  1st Owner
# 2      0  Petrol        SUV     7,100    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback    71,574       Manual        2  2nd Owner
# 4      0  Diesel        SUV    50,000    Automatic        2  2nd Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1376   0  Petrol  Hatchback    10,000       Manual        1  1st Owner
# 1377   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1378   0  Petrol      Sedan    50,000    Automatic        3  3rd Owner
# 1379   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1380   0  Diesel        SUV  1,20,000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  ...  Battery Saver  \
# ...

# %%
## # Assuming final_df_chennai is already defined

# Specify the file name
file_name = "final_df_kolkata.xlsx"

# Save the DataFrame to an Excel file
final_df_kolkata.to_excel(file_name, index=False)

print(f"DataFrame has been saved to {file_name}")
# Out:
# DataFrame has been saved to final_df_kolkata.xlsx

# %% [markdown]
# ## FULL DATA:

# %%
import pandas as pd

# Function to identify duplicate columns
def find_duplicate_columns(df):
    return df.columns[df.columns.duplicated()].unique()

# Check for duplicate columns in each DataFrame
duplicates_chennai = find_duplicate_columns(final_df_chennai)
duplicates_bangalore = find_duplicate_columns(final_df_bangalore)
duplicates_delhi = find_duplicate_columns(final_df_delhi)
duplicates_hyderabad = find_duplicate_columns(final_df_hyderabad)
duplicates_jaipur = find_duplicate_columns(final_df_jaipur)
duplicates_kolkata = find_duplicate_columns(final_df_kolkata)

# Print duplicate columns for each DataFrame
print("Duplicate columns in final_df_chennai:", duplicates_chennai)
print("Duplicate columns in final_df_bangalore:", duplicates_bangalore)
print("Duplicate columns in final_df_delhi:", duplicates_delhi)
print("Duplicate columns in final_df_hyderabad:", duplicates_hyderabad)
print("Duplicate columns in final_df_jaipur:", duplicates_jaipur)
print("Duplicate columns in final_df_kolkata:", duplicates_kolkata)

# Example: Renaming duplicate columns in one of the DataFrames (customize as needed)
def rename_duplicate_columns(df):
    cols = pd.Series(df.columns)
    for dup in cols[cols.duplicated()].unique():
        cols[cols[cols == dup].index.values.tolist()] = [dup + '_' + str(i) if i != 0 else dup for i in range(sum(cols == dup))]
    df.columns = cols
    return df

# Renaming duplicate columns
final_df_chennai = rename_duplicate_columns(final_df_chennai)
final_df_bangalore = rename_duplicate_columns(final_df_bangalore)
final_df_delhi = rename_duplicate_columns(final_df_delhi)
final_df_hyderabad = rename_duplicate_columns(final_df_hyderabad)
final_df_jaipur = rename_duplicate_columns(final_df_jaipur)
final_df_kolkata = rename_duplicate_columns(final_df_kolkata)

# Now you can safely reindex and concatenate the DataFrames as before
# Step 1: Get the columns from the DataFrame with the maximum number of columns (Hyderabad)
columns_hyderabad = final_df_hyderabad.columns

# Step 2: Reindex each DataFrame to have the same columns as Hyderabad, filling missing columns with NaN
final_df_chennai_reindexed = final_df_chennai.reindex(columns=columns_hyderabad)
final_df_bangalore_reindexed = final_df_bangalore.reindex(columns=columns_hyderabad)
final_df_delhi_reindexed = final_df_delhi.reindex(columns=columns_hyderabad)
final_df_hyderabad_reindexed = final_df_hyderabad  # Already has the full set of columns
final_df_jaipur_reindexed = final_df_jaipur.reindex(columns=columns_hyderabad)
final_df_kolkata_reindexed = final_df_kolkata.reindex(columns=columns_hyderabad)

# Step 3: Concatenate all DataFrames into a single DataFrame
full_data = pd.concat(
    [
        final_df_chennai_reindexed,
        final_df_bangalore_reindexed,
        final_df_delhi_reindexed,
        final_df_hyderabad_reindexed,
        final_df_jaipur_reindexed,
        final_df_kolkata_reindexed,
    ],
    ignore_index=True,  # Reset the index after concatenation
)

# Verify the shape of the full_data DataFrame
print(f'Shape of full_data: {full_data.shape}')  # Should print (8369, 200)
# Out:
# Duplicate columns in final_df_chennai: Index(['Seats', 'Max Power', 'Power Steering', 'Power Windows Front',
#        'Power Windows Rear', 'Low Fuel Warning Light',
#        'Accessory Power Outlet', 'Trunk Light', 'Rear Seat Headrest',
#        'Remote Fuel Lid Opener', 'Vanity Mirror', 'Air Quality Control',
#        'Remote Trunk Opener'],
#       dtype='object')
# Duplicate columns in final_df_bangalore: Index(['Seats', 'Max Power', 'Power Steering', 'Power Windows Front',
#        'Power Windows Rear', 'Remote Trunk Opener', 'Remote Fuel Lid Opener',
#        'Low Fuel Warning Light', 'Accessory Power Outlet',
#        'Rear Seat Headrest', 'Cup Holders Front', 'Navigation System'],
#       dtype='object')
# Duplicate columns in final_df_delhi: Index(['Seats', 'Max Power', 'Power Steering', 'Power Windows Front',
#        'Power Windows Rear', 'Air Quality Control', 'Low Fuel Warning Light',
#        'Rear Seat Headrest', 'Multifunction Steering Wheel', 'Cruise Control',
# ...

# %%
## # Assuming final_df_chennai is already defined

# Specify the file name
file_name = "full_data.xlsx"

# Save the DataFrame to an Excel file
full_data.to_excel(file_name, index=False)

print(f"DataFrame has been saved to {file_name}")
# Out:
# DataFrame has been saved to full_data.xlsx

# %%
full_data.columns
# Out:
# Index(['it', 'ft', 'bt', 'km', 'transmission', 'ownerNo', 'owner', 'oem',
#        'model', 'modelYear',
#        ...
#        'Power Antenna_1', 'Integrated Antenna', 'Tinted Glass_1',
#        'Rear Spoiler', 'Removable Convertible Top', 'Roof Carrier', 'Sun Roof',
#        'Moon Roof', 'Side Stepper',
#        'Outside Rear View Mirror Turn Indicators'],
#       dtype='object', length=200)
